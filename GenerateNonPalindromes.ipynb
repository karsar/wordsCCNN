# %%
def all_subwords(word):
  # get all unique subwords of the words and present them in a sorted way
  subword_list = []
  for j in range(len(word)):
    for i in range(len(word)-j):
       if word[i:i+j+1] not in subword_list:
         subword_list.append(word[i:i+j+1])
  return sorted(subword_list) 

def m_matrix(lmbda, mu):
  # lambda and mu are subwords of word
  M = {}
  for i in range(len(lmbda)):
    for j in range(len(mu)):
      if lmbda[i] == mu[j]:
         M[(i,j)] = mu[j]
      else:
         M[(i,j)] = '*'
  return M   

def Gamma (M):
  # constructing graph corresponding to two subword matrix M
  gamma = {}
  for el in M:
    gamma[el] = []
    if (el[0]+1, el[1]+1) in M:
       if M[el] != '*' and M[(el[0]+1, el[1]+1)] != '*':
                gamma[el].append((el[0]+1, el[1]+1))

  return gamma
def DFS(temp, v, gamma, visited):
    visited[v] = True
    temp.append(v)
    for i in gamma[v]:
        if visited[i] == False:
                temp = DFS(temp, i, gamma, visited)
    return temp

def connectedComponents(gamma):
        visited = {}
        cc = []
        for el in gamma:
           visited[el] = False
        for v in gamma:
            if not visited[v]:
                temp = []
                cc1 = DFS(temp, v, gamma, visited)
                cc.append(cc1)      
        return cc     

def wc(cc, M):
  #list of words from connected components
  wcs = {}
  for c in cc:
      w = ''
      for i in c:
         w += M[i]
      if w in wcs:
         wcs[w] +=1
      else:
         wcs[w] = 1  
  return wcs

# %%
import numpy as np
import random
import string
import math

from numpy import asarray
from numpy import savez_compressed


def random_string1 (N):
  return ''.join(random.choices(string.ascii_uppercase[:-10], k=N))


def check_palindrome(s):
    return s == s[::-1]

f = open('nonpalindromes.txt','w')

for count in range(0,2000):
  word =random_string1(20)
  while check_palindrome(word):
    word = random_string1(20)
  f.write(word + '\n')
  print((count,word))


  subwords = all_subwords(word) 
  dim = 210 
  
  pairs = [(a, b) for idx, a in enumerate(subwords) for b in subwords[idx:]]
  m_matrices = [m_matrix(el[0],el[1]) for el in pairs]
  gammas = [Gamma(m) for m in m_matrices]
  ccs = [connectedComponents(gamma) for gamma in gammas]
  wcss = [wc(ccs[i], m_matrices[i]) for i in range(len(ccs))]


  mtensor = np.zeros((dim,dim,dim))
  for i, el in enumerate(subwords):
      mtensor[i+1,0,0] = len(el)
      mtensor[0,i+1,0] = len(el)
  mtensor[0,0,0] = 1
  for i in range(len(subwords)):
     for j in range(len(subwords)):
         if (subwords[i], subwords[j]) in pairs: 
             position = pairs.index((subwords[i], subwords[j]))
             mc = wcss[position]
             for el in mc:
                if el == '*':
                  mtensor[i+1,j+1,0] = mc[el]
                else:
                  wpos = subwords.index(el)
                  mtensor[i+1, j+1, wpos+1] = mc[el]  
         if (subwords[j], subwords[i]) in pairs:
             position = pairs.index((subwords[j], subwords[i])) 
             mc = wcss[position]
             for el in mc:
                if el == '*':
                  mtensor[j+1,i+1,0] = mc[el]
                else:
                  wpos = subwords.index(el)
                  mtensor[j+1, i+1, wpos+1] = mc[el]   
  

  data = asarray(mtensor)
  savez_compressed('data'+str(count)+'.npz', data)

 

f.close()
# Out:
# (0, 'EMBEAJIBCOOCMCJHGAFM')
# (1, 'IICMNOBAINLNGCNPJGEK')
# (2, 'PDBCBPPBJCCDLLKJFGDH')
# (3, 'PBIKHFCANDDJGEFNCFJN')
# (4, 'IDEFLCGPKHBILNGJCGIB')
# (5, 'MLKFLCJNMCKOGHFNGGAK')
# (6, 'NOGPMMKHIKGPPJNKDDAG')
# (7, 'NANBKLBLPFKIBAFCAEFD')
# (8, 'HJGJJHHAELDPOPPHOKLA')
# (9, 'BNMPGJKHPEDKACLKNAKD')
# (10, 'KLKABHDANCANGPLBLBII')
# (11, 'APGFDEHBHAPBHMLHBJKM')
# (12, 'CPEMHNNNAEIOEJMELKAK')
# (13, 'DMGFCDGOOPDDNOBBAPGN')
# (14, 'ADNPFIPHCIFIKEIAPLBN')
# (15, 'GHDJALIKOBKEFABCDMDO')
# (16, 'ANNOFGBLJIGKJJMBGHOD')
# (17, 'LJHMIMCNLEGGMPKFDGHK')
# (18, 'PMBAGBMDDGMOFMMPJBMP')
# (19, 'NPAANPFPLDHCNIEMOIPC')
# (20, 'GJLJLLJNOHBPIHFCPFIN')
# (21, 'AIIMLEJHCPLIAOJHFFDN')
# (22, 'CGJLOFKNMGBFLOACCILH')
# (23, 'JMLFONEPDCFPPNMDKCCH')
# (24, 'PAAGFJGIOKHCKBAELDIH')
# (25, 'IAAKBNJFAIAEGJFNGGCP')
# (26, 'OILIKPLJHMLINOBJGBAL')
# (27, 'AAGOODPMFDHACBBKOPPF')
# (28, 'AJNJCJOCAOCFDEAJGCMO')
# (29, 'OBCFMOCANEOGEOJOOMHG')
# (30, 'PFFMJAFKIIKNOHMELBNG')
# (31, 'HLEODHPCGFJJLCOILDIA')
# (32, 'OGKEDHKFFBMKPMEALHMD')
# (33, 'HGGHKFPHOOPMKHKMDAFI')
# (34, 'AIPEPNOLKKDJCIPIAPNP')
# (35, 'MIFBGLJEKKFGBGPGOOGE')
# (36, 'BJCEEBOJIANHMDJPOAMF')
# (37, 'CAAFPBLHFKGJMDKLKDCF')
# (38, 'EFEJBKBCHJLKHDPPBFJK')
# (39, 'KHIGFKJGJFKFLNJFDHIF')
# (40, 'AHOHEBGCKIJGLOOGBIJO')
# (41, 'OFIPFBOCDJCFECALOJGL')
# (42, 'DEGPDAANMLJPDFJIIJCF')
# (43, 'AGGNJOMFMBANNOOMDFCI')
# (44, 'MKAPMFEIHKBGKKBOPCKP')
# (45, 'KDGGIFHEGNHELIOJPOML')
# (46, 'GCIAEFKEGEDAJAHHIPGO')
# (47, 'JMHLDLHNDMFEDDPFMPNB')
# (48, 'JBHICAADPDBHKFDBEKJN')
# (49, 'ABKGKMOHBNPIGIPAMAME')
# (50, 'DNLKDHPDOAMONCENBNCI')
# (51, 'LOBOAELAGFPJNFCDBLEJ')
# (52, 'GHMENFKNNGIMNOJPNBJC')
# (53, 'HEDHJNFLICHBMPEBIAEK')
# (54, 'LBJPJIFOEAFKKBOAKGPJ')
# (55, 'CFOLAAOGBCEPKONBCAAN')
# (56, 'DBCPBICEGCOFJGJAKNPC')
# (57, 'OLBLNBCFCOBIELNHOFJI')
# (58, 'FAGCKHEAAOKLEEDBIFEE')
# (59, 'AAOPGKNEGGLGJJHBHFND')
# (60, 'EDFOGMAHCDKNKBKODNKG')
# (61, 'PEEOCLIGNFJIKMLAJIJJ')
# (62, 'KAJKMNEIDMEJKDHHFOHP')
# (63, 'NGNMONGMIGCBPIOLACOL')
# (64, 'DGKBDCEDBNALMAAGHMFC')
# (65, 'NFCGKOAPNONBEOFABBAG')
# (66, 'KJJNCKCIIOIJIBPNOEGA')
# (67, 'HLJMHGDHOFHGMNCJHABP')
# (68, 'IDEHAHONIAPEANDEBIKP')
# (69, 'AIEMNCFPEFFOLNOMFCOE')
# (70, 'FOKABPFKEBFMKJAAOMPL')
# (71, 'LNPJCEDJBBAHLDFDICBO')
# (72, 'PEJOMMGHCJAMMGMAKMIF')
# (73, 'DEDMMKGAHEDPGBPMJGNN')
# (74, 'JKGFPKKFJDNJFHAJIMMP')
# (75, 'EFGHCCCMPBDDDHDPGNAI')
# (76, 'BJPOPPJMJJLGAMOJEEEH')
# (77, 'DPKLLLFADCEFMGBHGKNE')
# (78, 'HLHMMNIFAMBLJDLEBODH')
# (79, 'PHCGCBMMCJDNDNOOGHNM')
# (80, 'BLDFLOAJKACJPIEEFMIA')
# (81, 'NFHEPCNBBOIGCDGHABJM')
# (82, 'EBLMLKNDOKECPDEJBHKF')
# (83, 'JKIDGJPFAGBCACPMOCMG')
# (84, 'OAMDDJEGICOILBMEINLI')
# (85, 'FBLEKGFJFEGNNLIJLAHI')
# (86, 'MOJDNGODAOIPBFIPHPCO')
# (87, 'BDJOHDFNAEILIEPAMPFF')
# (88, 'BCKGLHDFKCEJHFPGCEOB')
# (89, 'PFMBKABPAKEINGEHDPFO')
# (90, 'GOALIOOLCBKDJPOPFBHO')
# (91, 'ALHDPKEANNMMMHFKGBKA')
# (92, 'POKKNLDDNJODCAELFJJJ')
# (93, 'ALJOMEJPMJDCNCECBKAA')
# (94, 'GBCCFAOMJGHMOJPLIFFN')
# (95, 'HKFMFHILDMBINBLKFFJC')
# (96, 'IODNHMPGCBPFDHHLJEKF')
# (97, 'NKHKKBABFMLGCKLIBPPF')
# (98, 'BOEHKIMDILEEAOHAKLCN')
# (99, 'PKOAMKFBDHFGJLBEHFCD')
# (100, 'FFEHLACAFKKPNEBIJLBD')
# (101, 'NMHHPHMGBMGIBBBAFMDG')
# (102, 'PLHJKAKGJHEFLOOAIGFP')
# (103, 'PKHINONBLIKNDBBKLBOG')
# (104, 'OPKIJMFPPNLNHGGDJKHD')
# (105, 'KJGLDFKDDHMGIKBCDOMF')
# (106, 'GCNKACGJOJMPLABGDFDL')
# (107, 'MFDPDIDOABCCJAABEKNA')
# (108, 'KLHBALDKCKKKNAKOHPAN')
# (109, 'NPIFBAOPLNKHPMLEDGAE')
# (110, 'PCNDEKKONOIPJIMPHLLE')
# (111, 'AMFDEIGLNJOLNLKONJAL')
# (112, 'KCAONKGPDMNNFOKDCNPB')
# (113, 'DJCOFKHGAAABBHFJBMGH')
# (114, 'NBKGGHPPJEBDFCGMOIJN')
# (115, 'GFJHPIMGKMNIKNJKAOBC')
# (116, 'IOIHFHHHAJNEEBMAJIGI')
# (117, 'IJHGJNMIMCCLOMJOGAAJ')
# (118, 'ONLPFJBEJFLBAEGKDDPM')
# (119, 'LHOBIPNCIMFEIHHBCNNP')
# (120, 'PMNHNIBALOJEHOKLAGAO')
# (121, 'FBACOOHIPEOHJGLBIIAB')
# (122, 'LOOOMEMEJNHGIMIFLPOA')
# (123, 'BGIEFGKBDILHILODEAEG')
# (124, 'CONHGIBIKJKGCKEKJDHN')
# (125, 'GJLGGCGEDAGBOGHPDAHG')
# (126, 'PKFCHIKBEMDKJBCMHFBE')
# (127, 'OPMMGGIPJOIHEOOIDDLJ')
# (128, 'EBGEDLPIGIBLOBHGJLJD')
# (129, 'GCLCDCGMAMEIMANCLGGH')
# (130, 'JOPCDENHCGKHJGPGDCFA')
# (131, 'JKLIHJOBHNMEGNMOBHHA')
# (132, 'KEJAMDJAALFFDDOEOJOL')
# (133, 'GLIFJPPELCBJIGOJGHEJ')
# (134, 'DGGHBAAMBBDBIHDELGGG')
# (135, 'NPLPBJBAKGLABNMHOAFD')
# (136, 'EOAOCEMFOOFCAJANAFPK')
# (137, 'FCIKGHPOJGFGANPAHFND')
# (138, 'CJNKKHECHPIKPKNCKJCO')
# (139, 'LFKHICHPHCODLBDOPKHD')
# (140, 'PFBMBMPMPDPKMANBMCKA')
# (141, 'LACENEIMLDPMCKEHOGNI')
# (142, 'IBJPPHEPNLNCNPGGJDHI')
# (143, 'JPKLMBLEMGMEIKEPCOPB')
# (144, 'IGIEOGGLEGGJJIHNGIDI')
# (145, 'JOIMLGHOFBLGGHOKOADF')
# (146, 'OOGDHBNODNPCMHMDJHFP')
# (147, 'KEEJIIBKINMEOBIFHPBI')
# (148, 'GMEOJPFACHAGAJAHHGIK')
# (149, 'PHGLCOOCBMFJIFBMJPBB')
# (150, 'ACEGMCODHPFCMOOACEBA')
# (151, 'OCOBEHPPLMONBGBACBBC')
# (152, 'ILLKPDHNNHIGEGDFODLI')
# (153, 'BHCLLGDFDNKGKPAHFAKN')
# (154, 'GGEKMMPLOPMEPJBKLPGG')
# (155, 'IBNBBPCMAIPOMFMDODFC')
# (156, 'NCPKPOMOAMKEDCBEEMPA')
# (157, 'FEPFENFEHAFDGIDPMMMA')
# (158, 'MLIIEEBJOAIGKODKFJKE')
# (159, 'DNPGDCFHFNPNBJDIKDNL')
# (160, 'JMFEJILJPLJKCGCJJELF')
# (161, 'PLPPCEDGPOLNPBHJBNJJ')
# (162, 'HIDDONFPMBKODADCDAII')
# (163, 'KDAMBOENPFMFIPFBPOPI')
# (164, 'IPHOAGGGIJCCPMDIIACA')
# (165, 'AMFAPGFBHBAMJBHCHPOK')
# (166, 'OCPAIIAFJMCICBOIEOEL')
# (167, 'GDKIGFBPFIAMFCMCGNAL')
# (168, 'NDNNMLKEGILPKFBBGIKI')
# (169, 'DLNIOCHFHALOJAHIICIF')
# (170, 'LGIFIEADJGOBPBMNEEBF')
# (171, 'FNDDGLOLKEKPBNLCBOLA')
# (172, 'OEHPBODMCCOFAMHMJMAK')
# (173, 'GKKHFGAHHMBIGLCLMIJJ')
# (174, 'KJOBOMMEKENOOKAPKEAA')
# (175, 'JHACJHEONOPCMGOBFGPO')
# (176, 'MIDKOLMIIHANNNEDCJPH')
# (177, 'FGHCIJGKOOAIKNEPHJOA')
# (178, 'HPALNMDOHDPFKJNGDNOA')
# (179, 'KKEIHCNKPMJJFDHLBGLP')
# (180, 'KEGDAMEDKMPCGELKDHIB')
# (181, 'ACCEOKCHGLFEEMGCPAIH')
# (182, 'GECHONBELMFDICAMOCOD')
# (183, 'GAENBHLCFOLPFNMAPLON')
# (184, 'NGDLMMOAHBMLMILLKMHI')
# (185, 'HIHNLDNNJIGCGCNLDNPG')
# (186, 'LMKGFBCKCGGHLMDHHHLP')
# (187, 'COKLIFAPCKAFOFKJNNDE')
# (188, 'BBPANEBJBLIAMHEADLDK')
# (189, 'IPCFGGCLEDJFEKIEIECI')
# (190, 'NAGGINGIHAJINGGNFJKC')
# (191, 'FNAKNNNOBEFEJABPENAD')
# (192, 'GCCFGEGNBLJOCFHCANCI')
# (193, 'BKLJFGCLOAPKLDHDDDGM')
# (194, 'MEEEFHHHDIPMLDMPLBNC')
# (195, 'EOGADBKAKKMPIIDKBNDA')
# (196, 'FNHBKDPEFDOFGOLDNJAM')
# (197, 'BGNPHANKFEEAFHKFDJBG')
# (198, 'HJIIDMGLHGEKNDJPEAOO')
# (199, 'DDAAADHBOHFMIDDNIDON')
# (200, 'NACLJHKNKMENHCCMAEKI')
# (201, 'LJGIOGJLAPKPFEFMPMJH')
# (202, 'JHIFPDAHPDLPAAGEFAEC')
# (203, 'AJDCKJONOMCBCNPJGAJL')
# (204, 'IPCGPIGNHGHDKFBAIKBG')
# (205, 'KAINKLNDLJOLCDEADOOE')
# (206, 'CPHGFFDPHGMAJPLHKCKB')
# (207, 'LLJIOEJAOJONONPFKIPI')
# (208, 'OFLECODHLKLDKECHIFFD')
# (209, 'LPDOIHJBBJCGHCNFMEMJ')
# (210, 'CABIAAEFCLPJFACIMCLA')
# (211, 'OAEBLOPFKFOEJAKDFEMA')
# (212, 'OFHMFOCHHLHDNEBPJDOK')
# (213, 'EKBPBGOALFMFBGFDMIDK')
# (214, 'MFALOJPAIIFIDELOHMED')
# (215, 'PELGNJLLNNPFOHCEILNL')
# (216, 'JGCFHILEIGFJMLIMHCOF')
# (217, 'MAEHOOHAEABOCCIHHCFE')
# (218, 'NJLOPBFAMJILPKCONFPH')
# (219, 'MGCCIPOFMLFDAAKCGCHE')
# (220, 'CNCPFADCKDGGLJBOIAOC')
# (221, 'EGCILPOJFPKEEBPIIIEP')
# (222, 'EFEJFKMPLCPDBAEAOLJE')
# (223, 'BHHGMBKKCEFLJGGBHFFI')
# (224, 'ODAOFGOELGGFHPLMLHHM')
# (225, 'LMDCCDLEAKIGGEIOCPMB')
# (226, 'EJOMJBDLLCBKAJIJHIAE')
# (227, 'FIFFKPNDKFMABGNBOOBC')
# (228, 'CBDKGKNPDGOEDHAEDKOL')
# (229, 'CNKBBCKBJFAOIFEBIMGF')
# (230, 'NBNKIOIBPOCIDHCADFID')
# (231, 'CMGLCJIHMAPKMDONAIJG')
# (232, 'HGLOFPEOBEFDHJPDBIEF')
# (233, 'MMENHALMPFHEODCPPPNM')
# (234, 'KNDGMDJFKKBNCOAIKOCO')
# (235, 'EFDJFDCENCGLDMFJECDK')
# (236, 'ELGDEJALNIBPAGCGKMCB')
# (237, 'FHNIHMMGGGLKMNLGIEJN')
# (238, 'FPKCHDLMMOIPPJMHGGPO')
# (239, 'NDBMNDLNJNGPHHILHFLD')
# (240, 'MCCHBEMOELOHDODLHKFJ')
# (241, 'MLCJHCHKKJLOMMDMDJEF')
# (242, 'GKCLLEHJFAEHNBBMCHJD')
# (243, 'BNMEMBLPGODHCDGAEJNG')
# (244, 'ACNNJNCPBBPMNDOCNEBL')
# (245, 'FNBJFCPCLHPJPDDANINK')
# (246, 'KJDGICNMFPAHPDJAKADL')
# (247, 'PHOMMMNNEGNNDJAMOPAO')
# (248, 'APHLAPHHDJGBLLKNAFLI')
# (249, 'EOKGNKCNCODBMFHFJELN')
# (250, 'GNIDPFALKPGHBNBCEKCE')
# (251, 'DCFEPFPNJEDDKMNJKIOK')
# (252, 'JJLLPNOGJIPCDDDACAKN')
# (253, 'FOHMOPHEOIBBNPAHDEFL')
# (254, 'ILHHMCOMNNLIBBFPKAFI')
# (255, 'BLIFOECKKFJBJEBBOION')
# (256, 'DCPBDKKMKLBBJKMCBOLF')
# (257, 'AKDLBEGJPMBKFOPJKNMA')
# (258, 'MHJEHMEDKPNNJJKIAMBI')
# (259, 'EOJHPOMDIEKCFBLPFHOK')
# (260, 'BPDKEGGGKAFLIHCCHGEK')
# (261, 'HFGEJNDHOBIOFCAIECKP')
# (262, 'MEEMMCBDFHIDPEGIAGCK')
# (263, 'MAKPNPBEJECCGFIBLCHK')
# (264, 'EGEJLPCNLMNMPMNGEBAM')
# (265, 'OPJLFJJCIJBIBEJNDBEM')
# (266, 'ANHBGJGNJKOEGOIDINBC')
# (267, 'HDNJMGLPLJFGDOLELCKF')
# (268, 'OCNMCANCKBLNEEALHAKM')
# (269, 'BELOMFCFDGKIMMBBAHKK')
# (270, 'IGHJJCNDBONEIAHBDFOF')
# (271, 'FHKDOHMBBGADAEEFIPAO')
# (272, 'NOGEPAKGMJFLMJBCGLLG')
# (273, 'DIEGEKGCLILGCCLBJPHD')
# (274, 'NNGPDOFAHHKAGAKGMEII')
# (275, 'OMJHLMCPHNNHJMIODCEJ')
# (276, 'OOCOKCANPLGFMOFJAEDB')
# (277, 'OMADCDPFKCNLJJDMGLCF')
# (278, 'DFHDOMDKENCDHFHHKGHF')
# (279, 'LDLHLJDFMKACOCJNEPBO')
# (280, 'EOHMHPCEEHCOEKIAOMEH')
# (281, 'ILLNLNJODPJPKEFFMEKF')
# (282, 'GKIGFIJPMPCKFCDHDGCK')
# (283, 'NCJHBDNEJKEKPOODPIPL')
# (284, 'DJPHPADAAPKLHJMPNPEL')
# (285, 'OAANECDGBGBAJGPOENBI')
# (286, 'FPJPMFJCPCJKKCKANKAD')
# (287, 'HPFNLNOHPFIBCMGKOHJI')
# (288, 'ACOAELCPJJLIKJOPCELE')
# (289, 'DFJHIACMEGANFPCABANF')
# (290, 'IAFCEIABLFDNANCNENMK')
# (291, 'NFPOKDDFMMBGAILLFOJH')
# (292, 'ALNOBKMJEEEBNIKEHBMJ')
# (293, 'CMELMNOHGKKPGDMOBCFM')
# (294, 'CJEBCNEOPKNFAOIPFIIJ')
# (295, 'AEHHKACBBHCCAHBLCNCC')
# (296, 'DMMBAMHAIPECNDFPECLB')
# (297, 'JFEECEOOADOAPLGFMAKJ')
# (298, 'AKFMHNNHAJIKMLMEMECF')
# (299, 'HFABOPBEDHMNHNCANJHH')
# (300, 'EDIHJKFGMDFAPJNEMMCH')
# (301, 'NMFOGFCMNAGCFBGGDJEK')
# (302, 'FMOIFMJDFPKDEDPKBECA')
# (303, 'KMEEINCOECMCJNDFANCL')
# (304, 'ALLGHEFALFMIJODADJPF')
# (305, 'KLPFGKJLOHCGLHNGJEDD')
# (306, 'OALGMJHPGJKMFFNNOJOG')
# (307, 'OALHPCDGDIEOFDNDCFKC')
# (308, 'EPGLOMGMNEGAIFHGAPLJ')
# (309, 'IAPLJCNBMMHPIOMFBCJA')
# (310, 'EKBFKGLFDCBLJFJOFGAP')
# (311, 'MKJLENGNHKMNCMNIGCKH')
# (312, 'DBJDBKHGCICDNBCMDNAD')
# (313, 'PDAMLEJILGBFDMNHLEGA')
# (314, 'AJPMMBIOJBHFGFDADAOK')
# (315, 'HCFGPFIGELPNDDBJMMPI')
# (316, 'CIJOOFPFOICHHDIJNFBG')
# (317, 'PCIGDOBDCHBPGBKEMCFK')
# (318, 'AOHIFNBODGIDEIJBFOME')
# (319, 'PJKBHHFHFFELBFJACMAI')
# (320, 'EFIFCHBPJHALCHFDIKFG')
# (321, 'OCKNMFFHOJGKEMPJOLOB')
# (322, 'IPCGCALLJNNHAEOPBNBK')
# (323, 'NDNMDDFLEGJFCOIBFIAN')
# (324, 'CODPJBJMLIDJOLIPCCCM')
# (325, 'FNNJNFAFGFKLPDLDLGKJ')
# (326, 'AGGEEOAFNHPLJLMFFEJF')
# (327, 'FCEACNLCNPMAPFNALPKC')
# (328, 'JHBLNLBKEDGEHBGJIPKA')
# (329, 'HOKCHCGBBFOGJFBHCAAM')
# (330, 'FLMCEDPHBHOBKFOABAOF')
# (331, 'AKIIENLCHLFHCDCAOKCM')
# (332, 'DLPNLADCBOPGIDHCCMFD')
# (333, 'ADPLALCNGPFCNNJOEJPK')
# (334, 'LBEIIFDDBIKNCDELDJBG')
# (335, 'FFOCKLDGEFHAEGIEOEOL')
# (336, 'NIDDMHHEDLJHEGAOGHJO')
# (337, 'PFKKJKLINBFJNOOJDBNI')
# (338, 'EFLBIMONANDCGDENIKDB')
# (339, 'EDCMIONMALPEAIBOADLN')
# (340, 'AIFMCOLMAABMCNGJACPL')
# (341, 'AGKMGCCDNPBFCMIOCKAI')
# (342, 'MDGCJIECCMJJJICEGEIB')
# (343, 'PKPEAJECAJOOGOMMGBKK')
# (344, 'HJMODHKEFBNNHJILKJAN')
# (345, 'MIFOLECMFGDGPCGIEPHO')
# (346, 'BFONPFLJFOHEGLCNNEJC')
# (347, 'OHNBEGGLODEHHBPFMCIL')
# (348, 'GAPNMCADDEBCCHHNEIHN')
# (349, 'MKPKJHCJHKELBBHFKEPI')
# (350, 'JNLGGCOBEAIEOAGECJJC')
# (351, 'BLIIKNLHJGECDPDCJDEN')
# (352, 'KGJDKFCMFCCPAPPCAALM')
# (353, 'OPPIFEMKNFJDIFBCECPK')
# (354, 'CDACCNIMFPEPEHAJPBPA')
# (355, 'KDLIAECAENPPNGEGFNPO')
# (356, 'PGPGBDAGKNDLGNPBKKFE')
# (357, 'GIPCHGGGJOJHFHKPKGLK')
# (358, 'NBGFIGHEIJMOEIOHMGLD')
# (359, 'NAHPEHHBPAHCPNHPOFJI')
# (360, 'KIIOHCPNCEMNNBKPOOBI')
# (361, 'DKCBABPHJOODIABJFDIF')
# (362, 'OADLLGCNKICGJBCNFPNE')
# (363, 'FAFPPHDFGFIGEFMKFGEF')
# (364, 'EIMONPLMPGHHNIMPDOOE')
# (365, 'JFJPBCJCLEAMOPAHNJGP')
# (366, 'KCCLADLAKNGPHALPICJG')
# (367, 'JBMLDAFEOIGCLMKPMPNN')
# (368, 'LOKMFFHDCCIIKNJBHBMC')
# (369, 'JCKBJIHGJFLBMLDIKEJD')
# (370, 'IKMEDAJKHNEDOCPAMPIJ')
# (371, 'MNPJEKJCKEBDMGNMIGPH')
# (372, 'JLCIGEJIMKKMNDKBDMKC')
# (373, 'LOLCCIMGLLEOIBHLBEMJ')
# (374, 'PHGFGGJOIJHDHIMFEFMK')
# (375, 'LJHBNHFFKKJHBGKLIDGC')
# (376, 'JJMMCHMFIKHBHOBEKHOL')
# (377, 'JJDIFOPENLPDBANLJLDJ')
# (378, 'CMMMKIMEENBBBKGKJOHP')
# (379, 'ADDAGNADIPLDBAELMAPJ')
# (380, 'NGKDHMBAMLPOODKMPHDP')
# (381, 'OMFDCHGAKOLADFIAOBMO')
# (382, 'LIPNBJIPEAJLDAENIEOD')
# (383, 'ILDOEDKHBJCLGPLADDGH')
# (384, 'KNEAFPDEHOMLDLIOFNJI')
# (385, 'LDFBMHHDNJEGIKNONIMH')
# (386, 'OMEJOGBPPCEDEGFFKBLE')
# (387, 'FJNLNMKCAAFBCOBDBFBC')
# (388, 'KDLHPJLGFOHBLKMMDEFO')
# (389, 'GHEDBIDIOINLHCKDJPGJ')
# (390, 'AAIJMDKDGNGFOPDIGLOD')
# (391, 'MDNBJDDKJLNGPOOAIGCJ')
# (392, 'JLIKEJKEEIFMBHFGDIKF')
# (393, 'NNEGFMPAKICDHKMHFPEN')
# (394, 'GBDMAODAGBFKKJDGCKGF')
# (395, 'CJHKNHEDCBGOKKPPGOGD')
# (396, 'LNMCHCNHFLABCMKLHMAB')
# (397, 'DDANILGJKHAHMIGCPNAG')
# (398, 'BJFMBOJAMMFIHIDKBFAI')
# (399, 'KMCECBBKBDOFNFNLMMNK')
# (400, 'OHGLIKPLOHNOPHDPILAP')
# (401, 'EMHFOHDOGCHEPBMELADN')
# (402, 'KCJGHJHECCMEMEFCLPEC')
# (403, 'HHHNEBBIFPBAOAIAOHAM')
# (404, 'FPHGNHMAIOPJNDJKLGHA')
# (405, 'LMIEFDLLBEBHLLKDJCPJ')
# (406, 'FDLNAEKJPFPGNEGOCMHB')
# (407, 'HKILKGJDAKPAJLMKBKFJ')
# (408, 'KEGONOKLCDODFBCJGMFK')
# (409, 'KNFFANMNOOEMDGKBGBHP')
# (410, 'HBLMKCKFOGDJKLGCNEII')
# (411, 'AJEPBIFEEABDNHNHPMIO')
# (412, 'NIKJNBNFDFODKIGGMALK')
# (413, 'BFHIMCJJKNJNJCEMPFLN')
# (414, 'KANMOBFMHNLPGGJMMDMD')
# (415, 'OABAEPBOBCAIHOFLDJKF')
# (416, 'MPCCFOGDDAEJKCLJEIHN')
# (417, 'PGNMIMFCKAGDCLACAKPH')
# (418, 'AMLONAILJHKHPJCJGFHN')
# (419, 'BFCIIBOLKNPDABGFKCCO')
# (420, 'EHFEADBCHBINGKAJAHMK')
# (421, 'MALGMCBKCIMGLOOAMLEJ')
# (422, 'PDFOAKFMIBKFJBBINFJM')
# (423, 'DKHJLHKDNIJMECIKJGLN')
# (424, 'PFHPACFBFDMNKNLBACCE')
# (425, 'ALLOENKGCKAIAKBIGEOH')
# (426, 'KFJIGLOGJNGHGAGPFBEJ')
# (427, 'GMMELPJNMNKPONNEDFMK')
# (428, 'PKEGDKCNPFHAKGGCLLOP')
# (429, 'EAADAJPJINFMPADOPLPJ')
# (430, 'KBKDAPBIHBPLGJCGEHAC')
# (431, 'LAOCCMIPOBFGHGFEAHKK')
# (432, 'MAAMMOKNFEGGLKMFDPHB')
# (433, 'NOPNPFBPEECADHDBDKML')
# (434, 'PJHEIJMEPHJMABGLGJJJ')
# (435, 'GNBCFPCLGFDAMBAFJAEO')
# (436, 'GNOEJIFHFDHPKPFKDNBI')
# (437, 'HEMKFOMLKDGODDMGPHLO')
# (438, 'BBNPHKHGDILCJCFGAOCN')
# (439, 'GPGEJJFAHBMKOGGHEEMM')
# (440, 'KEBKLECBIIKLBEIACGPD')
# (441, 'NPCELENIDKCKPICJLEKE')
# (442, 'CGJACCKFALJHBMAIIJDI')
# (443, 'PBEKABMODOKKGKLDKBMJ')
# (444, 'JCNMGAHPOEEGBAHGKMLJ')
# (445, 'KGIKIFJNCMIBCLMDEPLA')
# (446, 'BPPMFOOCEMLOOCNAAIGK')
# (447, 'FKHOLAEEAPKNFFLMAOHJ')
# (448, 'GGEKBJDIDAFMNMHMDJLM')
# (449, 'KILNHBKBPMAMOHBGFNBL')
# (450, 'GHNKOGMLEACECIAEGJOJ')
# (451, 'JPINNGADPCJAEMJLENHE')
# (452, 'FCOHDCPOLIMFFILKBCLP')
# (453, 'OCJLNOKBKPLKOLLJMGDD')
# (454, 'LBICFGJJPLIMKAEGICNJ')
# (455, 'EECJKDDAMHELNLFEMJOG')
# (456, 'OLPIACDGJICNEACOFJDB')
# (457, 'FFKBMJIIJBJBEDKPFMDD')
# (458, 'ICAKKIGNGPDGKENAMPKF')
# (459, 'DIIALNCOAKICMLHFAMPI')
# (460, 'GFJJHANOBDICPHGLJODJ')
# (461, 'COGAJBGJNBJPGJIPIBPG')
# (462, 'MDCBNEPKINLDGAPHHFDI')
# (463, 'KHODGKNJKIEJBCFCOAFG')
# (464, 'FGFHAPLCDPHJINOPJAIM')
# (465, 'AFPFBPCDDHHLKGNEPNLA')
# (466, 'CGNDGHJOHNMBAIEAGHDL')
# (467, 'KFHCIFOBEKOKLFDNIADE')
# (468, 'JLABHHMOAAGHMLDLCGJL')
# (469, 'GPGCIDFBFMCFJODIEDFN')
# (470, 'FOJPHEGBLIEGNDGOKODE')
# (471, 'LCMDLNOLGHIHOOIFLCNI')
# (472, 'IDEJNADGACLNADAAEENC')
# (473, 'CDFPOCIKADJCCJPOALCD')
# (474, 'FMMNBBJIIDGBNENNBFHK')
# (475, 'INFJEDAPFEEJNDBGDLCF')
# (476, 'LLBFEDPKKLKDBJLHHBAP')
# (477, 'JNGPKMCJJOMLBNBKKEGA')
# (478, 'POIFFHJDINOBOJJNOHMI')
# (479, 'FIELGGIICKDMCKKINALA')
# (480, 'LPEENHBFNFAGIFJPMGAK')
# (481, 'FBBEPMJIBPBCBNPAAJJL')
# (482, 'KGPADKJHMMFHKJFCKALM')
# (483, 'LCANFFDAPGFOHKIMLCJK')
# (484, 'ONDACHJBBGNGBGGPKHAF')
# (485, 'KNLIKHFEPGFFNBFGFJBK')
# (486, 'KELMAAPHAONGLKEDIHDC')
# (487, 'LGILEKKCEBJBBCALFLLD')
# (488, 'JFICAKMOJBIFKPAIEIPJ')
# (489, 'DENHDNBBLEHLALHMMHPC')
# (490, 'EOHHAHIPJKMPPAJLBCJM')
# (491, 'LAOONEPKKFDAPCOAEDJO')
# (492, 'NAPDFGKFDGAONIPHJNHE')
# (493, 'NFGJOJMFKJJBHKKOIOGB')
# (494, 'OGMCMIFAEKLJCCFFLBOK')
# (495, 'DLCACOOHAGCAKMEJNGLE')
# (496, 'OBALOMMHOFEKKBFBGOMH')
# (497, 'IFIFKBEICGFHHPGJACNB')
# (498, 'KGDJOFAHEONANPPFJIDH')
# (499, 'IKDAJMGLNNILMJENGFGC')
# (500, 'IBNDAEPIBLGILDLNCNOC')
# (501, 'LPHIKHNNIHMIJNMEDMEG')
# (502, 'EFKDGJLNMDAAFBPPBJIH')
# (503, 'BGAMJOMEKBFFOKFEDHCF')
# (504, 'DKGHLFLPEANGGDMMJIMA')
# (505, 'GNPKGLIKBJPGDHGCJEJG')
# (506, 'FECHOEOGFNCJIAJBANCH')
# (507, 'EMDDIGNBDKFFIGGJKDED')
# (508, 'KPELPGJFGJABFDJIJJBI')
# (509, 'JJMEOBJOFCHGMNJMDMMK')
# (510, 'EHLDHOOEDPNHKFDNAIOG')
# (511, 'ANBAGJAPLCNKCNIMKJNC')
# (512, 'KHDNMIBBHGCNODOPLNIH')
# (513, 'NIDNGGMBOLAGNDHCODBA')
# (514, 'POKHNAAACCKNDLJMGDLM')
# (515, 'CIPHNGPNOABCGADKLAEA')
# (516, 'JPLILCKHPGPEICIPPLHI')
# (517, 'NKPKIHLIAGMFJGLLCAKL')
# (518, 'NPBAJMJBHODHONGLOKGM')
# (519, 'NFGPKNMBLGNEBBBPCNAC')
# (520, 'BPIINBBLJLCCILFGPIOL')
# (521, 'CCJFHGCODJLNEIIOHBFA')
# (522, 'LPKFEHNMCKANMLEJNFJL')
# (523, 'HGECIHDCLIMENKCKMHFJ')
# (524, 'HIDFOHMJGKKPIJJDPHMD')
# (525, 'HHHIILANCGPPHAGBMBFL')
# (526, 'HMCAFOILCAHCNOMFHMDI')
# (527, 'GPMDIKCMDEKGOGILEOON')
# (528, 'HAMNBPMFBCPNJGLONCFH')
# (529, 'OGLLPGAHMFACKPKHILJB')
# (530, 'LBHOGFMCMAJHHOMIEFJI')
# (531, 'AAHCIFGJGHJANHHEBJCC')
# (532, 'KNINLLOLGFDJDOHDJPKB')
# (533, 'EAFJOBLDFDDKDNOIBBAH')
# (534, 'KMEAOHMLBEANGJDEIFPK')
# (535, 'FFFNOMCAGIJPDHGMMIEB')
# (536, 'IAKFFNIHCPBFBDMDHNFD')
# (537, 'IGIJGPHGOOKFLDMBNOBF')
# (538, 'IICBFLIGGMBODAEKBDBP')
# (539, 'CJKKMACGBCKLGOFBCBJL')
# (540, 'NGDICEOEIPBNHENGHBCJ')
# (541, 'GGPDLJDAECLAPCECEJFO')
# (542, 'KCEMGEJFBBIFIOLDGCPC')
# (543, 'EODOFOFHPEDCLKHDLFMA')
# (544, 'LFNJKNDEOIAFHININDNL')
# (545, 'DGLDAHHDHGGACKHAGLAB')
# (546, 'CIHBIAJCPGEAEIDFBIFH')
# (547, 'MKJCFLMAHIBMBEBBLADA')
# (548, 'IHPDKKHDBNJOLLKCCGOH')
# (549, 'FOEJOFAPIHGLPGNKMJLE')
# (550, 'MHLEHKHJFNKLKFGEMLDD')
# (551, 'HMBPOLHJCGAOCCEGEKEF')
# (552, 'FICDOFMBCELGKPKMALKB')
# (553, 'MHCOPJGBNJIFLIBCBKLD')
# (554, 'AFFHDNJPCEMNIGGPCJNC')
# (555, 'GGMJJLFJLEIHCCIDCDHF')
# (556, 'OJLGEPMFLPFNCNJKAHDH')
# (557, 'AKMIBLEHJPMMOONOKJGK')
# (558, 'CELBIDKEEBOAACPFGHOI')
# (559, 'MGIKFKDGMOAOEDDHMDFF')
# (560, 'FCJIMLIKLFDOFBFJENMF')
# (561, 'FLJAOIBBMLBLMIHPJOHJ')
# (562, 'CDBKONBPHJFLDOLOHOIJ')
# (563, 'MMLCBFBKPJDGDGIDMENP')
# (564, 'NOEHKCNPIILMKLGODKNL')
# (565, 'DCDKGBDJMCHBJHKGHAHI')
# (566, 'AHGCJJJFPNENHGOPFIBA')
# (567, 'HNAPFBLHNGHKDHFKKFBN')
# (568, 'IGOOGGIHPMMJCMHJHLIO')
# (569, 'DJBIFHMACEFEOFNAECNL')
# (570, 'FDBHFPJOCHNNOMPEOFGM')
# (571, 'BFBIKHEDHGOOIPENCEGM')
# (572, 'HPMNOKAMOJDCCGAPALGM')
# (573, 'GPBPBHOCGEGDDOPBPEIL')
# (574, 'MOIPGHBEJMDJLAJOMCHP')
# (575, 'FFPCHFAAFFGNDNFMFEHM')
# (576, 'FBJAKOPFDMFHDKIOAFPF')
# (577, 'OIAMBFIKLPEFKGKNDBLL')
# (578, 'EDJFBCBLANJGNMCFIFCN')
# (579, 'EAHPAAHDEHGDIOJPNLOD')
# (580, 'NLAHOOJKOBMFOHHMFDCN')
# (581, 'NIIHPAEPAIMLJMHJEMIM')
# (582, 'NKJAJJHICCDPJEDHAAHM')
# (583, 'JBAFCBBNFMAOCFMODOON')
# (584, 'AGOOFMOIEKPLFDCHIMDI')
# (585, 'GKDKCCIMPOCNMPMFIHNL')
# (586, 'EIPGNAIEEDJFDNEFCHMJ')
# (587, 'DHNONEPKPHPIMGBCINMO')
# (588, 'BCCMPMJAKKMAKMPGBNLI')
# (589, 'JFLFIFCLFDFLPPNLMPLH')
# (590, 'CNLHJJEMOAPFPPEEEAPG')
# (591, 'LJNPMDFPEAJHHEFJOFNJ')
# (592, 'ECAPENOJLDJFOGCFJCHH')
# (593, 'AMDHFCILENMLHDJBOOFF')
# (594, 'EKIEINBCLKOOJKMJNIPP')
# (595, 'OBJPFACLNGHKAIKBOCDE')
# (596, 'IKOPMHOOKAEBOPBPOIOC')
# (597, 'FLEKCFHKGFOMCBAINEGO')
# (598, 'FJKHCMAPJCIMMBKCHBEF')
# (599, 'JOMAONCFHCBJPOLEMEMB')
# (600, 'AAAEACGFGLIDDEBPJDIL')
# (601, 'KHCPFIKHGNBBKBHPDFMJ')
# (602, 'ABLBALDOEEPDOGHHLKAK')
# (603, 'EKLGGNCOFDNAOIFEPCFM')
# (604, 'JOAFBMPCPHBDKBIFBOJL')
# (605, 'AIDHPLJNDOBABCOHALAB')
# (606, 'KHFLIMKDDAAIAGFMOGFD')
# (607, 'INFOANGDHFAEIFHOPPJO')
# (608, 'JEDKFJFFLPHOOBBEKLGI')
# (609, 'NDKIPKPBHFCHGGNPAGNG')
# (610, 'ENHBPHGLFBDEHLFLJCHD')
# (611, 'OMKDFIOLMPLHPDAKPOBK')
# (612, 'LPJEFGBEBMPNPBKLPDOB')
# (613, 'POJIGLJLHNIFBIEILHEJ')
# (614, 'IHMMHOFNBPNBOGEFHJFC')
# (615, 'DEMIKIOHOONGNCGKPHHN')
# (616, 'JKIKNOIFIMGBJLMBMOPE')
# (617, 'AOABMOAPLIIIJLDDKHFN')
# (618, 'HGHCABNNBOPGLCCBLOFG')
# (619, 'DKGCJFPIPKDGDMHNDFJM')
# (620, 'EBFPAENEKFPBKAGDMJJP')
# (621, 'GGPEKKKFCIABOOONPNKN')
# (622, 'ENGOCFPNANGCPBIHCJDI')
# (623, 'CADDIGGPEOGOENJDBLFN')
# (624, 'LGIPECABFOJAGOEELHFA')
# (625, 'BJGCHAACHMPEJIPONBGM')
# (626, 'JBPNKHHCHIIEKAFOLGMM')
# (627, 'MKKOJPCKLGDIPMDODDEJ')
# (628, 'DAGBGMHONIFMMLPNAAEH')
# (629, 'PDFJPHCHKLIIOBABLKAN')
# (630, 'KCNLNJFBCNKCGFGPJKBM')
# (631, 'JEBIIFDOHAJKBDPKBJEM')
# (632, 'POONGMECHHBBPHCBELIP')
# (633, 'HFABHJLIFBKGKLFCLNCH')
# (634, 'HMAELACJDIJKMHGCFLGO')
# (635, 'BFABEFHBCHEHDIEDGNEM')
# (636, 'GPPJEPNOHPNDNGLKOJAG')
# (637, 'DDICHAKLLJPKOBMNGIAO')
# (638, 'DJKAPGIKHPFFGAAPIPOM')
# (639, 'OCGGHEGMAOENLPCNOJOM')
# (640, 'NJPEGAJBCMEECCNBCDAG')
# (641, 'GJCMPBHJICNDLCGBLFBF')
# (642, 'OIAHJIDPOCOEABEGMDMH')
# (643, 'NINGDMLJPOJHPEJFOCBK')
# (644, 'JDHMPNKEBGJABCEGDOBB')
# (645, 'JIPMDMPFDMGNLJFPJDJN')
# (646, 'OBPGAMKFGFLAJOEAKHIE')
# (647, 'DKFFEMLNNCILNNJEBAKM')
# (648, 'OLFBGLHMJBJIKIMAABGL')
# (649, 'BDEGEKNIAJAMIGFHIBJH')
# (650, 'GBPCDEJOBGGIIIEGMIDI')
# (651, 'MACJFIJDIEOIABDGKNKH')
# (652, 'PBGHDFGADNPPAFADDHGN')
# (653, 'OAEGLNHHGDIIJBFFLNNB')
# (654, 'EDLJCOEPPJAEPEHBMAOP')
# (655, 'PDOPNLHOPCNDCEEIGGJI')
# (656, 'DEBIKFNFDNGOEBKHEPBN')
# (657, 'EGHICMLDGHMFOPJCNJPH')
# (658, 'FBMHGBKACFLBICHEJLHB')
# (659, 'MMOGGCCLPDHGIDPKPPCA')
# (660, 'CDLFIPLACNCDBGBFAOBK')
# (661, 'ECGHOKOHKIHNMEAFBHJK')
# (662, 'AEHBEDGEGGGJDHGENDEO')
# (663, 'FIGLGGCNLFFGCPBLHEOJ')
# (664, 'OKDPLNIJIFPHPOBGLCDK')
# (665, 'IANDMODDBNENPBDNNNGO')
# (666, 'EFCAFIJGLOHJCJAKAJIO')
# (667, 'NOCHHKKNMDEFEBCLAOAP')
# (668, 'DEFADFACLFMEOKBBBEDD')
# (669, 'MJHNHIBMDBAIHPOIHNJD')
# (670, 'NAIDABIMLFNFOJMOJGBD')
# (671, 'HIOCJDEEEBDLEEEFMKHC')
# (672, 'FCABNJLBLCPEMNDGNDKG')
# (673, 'FLPIKFICDDHGEACHEOJO')
# (674, 'OJCGNDNLCEHHCOAJIJCP')
# (675, 'JHJPPIAJJHCMBAMGNKAC')
# (676, 'PJNBPCCMNFEFFLIHBAMI')
# (677, 'MOIMJLMLEDHBPMIAJNAL')
# (678, 'AOMIMCANIKNGEDIJONMM')
# (679, 'FGNDKOAEFFGIMKDGHMOC')
# (680, 'FCDEIPHICNHMJFNLHPME')
# (681, 'JDLIHKAIHJKGKCHOFNLJ')
# (682, 'PGDDOHGJEOMGBBOMICCJ')
# (683, 'GKKOBIKDIEGBKDBLHGEB')
# (684, 'EAJJBKACMBNFFBNNFPBE')
# (685, 'FOLOJOHPCPKLKGADCBNN')
# (686, 'PONIJELBKLKBKLFAOOFH')
# (687, 'PFMOOFPPFLDLCMNIFJHJ')
# (688, 'PDHMGAOKFAHBNLNBFGEJ')
# (689, 'NCGNDHONGKICNGAICOOH')
# (690, 'EHJKJPFJMILJCALOHOGK')
# (691, 'GEIOAOHNLJKHGNPIDBHA')
# (692, 'ICHNLBAHCOLEOLFICBBA')
# (693, 'GIJPPNNHEDGKPMEKPEIA')
# (694, 'BPDCCMBDKNCHDNIGJMCB')
# (695, 'JGOOJOJMMJFFICLMFKDL')
# (696, 'OHPEHNIDIAHCNNKFGCDC')
# (697, 'EPMOKDDBDGJEHPBMOJKE')
# (698, 'LOJFDIJDNHCKOEIKHFFG')
# (699, 'MBKBPJGIFKENLPOOFJGM')
# (700, 'FADLCBGGGMIMKFPABMHA')
# (701, 'MDHALPMJPCFNDEMAGLKL')
# (702, 'DPBLEIGFKAOOFIAPJEDC')
# (703, 'IFPFCPCIAHHOIBCHKLHM')
# (704, 'CBMLOEKKOGMPNBGCJADB')
# (705, 'NHGIJNCHECPMDBBPBIMA')
# (706, 'FOFKFNKKHKAHKNEMILKD')
# (707, 'ALFCKBAPFFMKGCIEEGEC')
# (708, 'OCGLFDONPNNMOLDIKNOA')
# (709, 'OGNBPKKCEOCKBHOJCMCO')
# (710, 'EFBPPEFLOCGGDHCIMJAB')
# (711, 'FMKOJBFDGDDNENDPJDDP')
# (712, 'FKEBNLKLBMECKFIEBNNO')
# (713, 'GDBOEPBJNIJOFNEKIIME')
# (714, 'ECEBMFEBMNHNILGPNJFO')
# (715, 'DIAPJOAOHLJJCHBCHJKK')
# (716, 'HPDDGCIFKEHEMPGMOMCM')
# (717, 'IPDIDMIGFBEDFFCDMGPD')
# (718, 'HMJHNBKIGMHOEONKDGKK')
# (719, 'KBBHBPJFFEJOIFDIKBHI')
# (720, 'MAJNCLMBEHHIOKFABBIM')
# (721, 'IMHDHADHIBJKDILMFGFO')
# (722, 'MGGHLJHDFKDPIMLKPDLN')
# (723, 'CNCNDFLNNDPAEKLEBKBJ')
# (724, 'OOOHPKPNPMNOPOAACOHG')
# (725, 'PDPONENLFNMAJAEIIMML')
# (726, 'IADGJNJOFLIDGKEPMPAH')
# (727, 'KKMIJOIKNIDOPBIHKCNP')
# (728, 'ODLCPDKAHCMHCDIMHMPI')
# (729, 'INFEPJAEPCIDMAHPBLOJ')
# (730, 'IDMEFLEKODHJLONHACHG')
# (731, 'MMFFHOHNADBMHEJJOAKN')
# (732, 'INHFMNBJNJBECPLDFNIB')
# (733, 'LDNFKDEOCPABNHFPIELG')
# (734, 'JJMIAJCHFLJABLEGEBBI')
# (735, 'JNPGJIECMBLGOAMPIIBI')
# (736, 'DBAAFHKAFGGADGKMKBEP')
# (737, 'LNINCHLMPFFCADNFIHMA')
# (738, 'GJHCLJMCFBAADIAOGIDL')
# (739, 'OJCJGAJPOIPHDIIFANOG')
# (740, 'HFDOHAAPJKPKIPLPPEIB')
# (741, 'GKHMCHGOOFGPAIIEMEKJ')
# (742, 'HEGCAACPKBNKEKAAMBOP')
# (743, 'PAPIGFIKLKMAFMMJEDGG')
# (744, 'AMNDDAFKNEOGLNHLMGLK')
# (745, 'HIJKDOIIGDOHHEPBAICK')
# (746, 'NAHDBLKLGBCBEFIEPDKL')
# (747, 'ANKICDNGBPHEONLLICCC')
# (748, 'OBDEKOKCMDOJDJMLMFFA')
# (749, 'PFFDIAFDKNLIHOPHAJLG')
# (750, 'LFHIOBFGHLPGADCNBBAJ')
# (751, 'KLNEPAMGNJOKCLINCAIA')
# (752, 'IPIFIHNKFOPBBBFLDINN')
# (753, 'LPABICPFEDMHNPMMAPCN')
# (754, 'POFCFOGHIDFALMKGAHMH')
# (755, 'DKGJNKJPMGOGPEHOADNO')
# (756, 'EBMAAOKGHENLAIPPGLNI')
# (757, 'IPKHPIPEBHDPIDDFJPAJ')
# (758, 'PJKHMMNGKBCGFMMIFGEA')
# (759, 'GHIKBGCACJPNLILDAHFA')
# (760, 'DINLCAICACBMAGEKOEBC')
# (761, 'LJPMPJADNBLMFOCMPOED')
# (762, 'JFALNODBGEDBNFMCAOKN')
# (763, 'PAAPFMPINONEEKKMHOFG')
# (764, 'CNAANDEKGJNFMJMOEGCI')
# (765, 'PCNHIIJALABOHJJFPENK')
# (766, 'GBHEDGMLONMKOLGDNJDF')
# (767, 'IIEEDNPGPIFPFJFKBNGB')
# (768, 'HJGNPCJIMIAHKOMCEIFD')
# (769, 'HGLLDFEDJKLOHOHHHEOM')
# (770, 'LKAFMCBFFCCCDHEKJEIG')
# (771, 'MFPFGCDAJGBNEHODOCPA')
# (772, 'MGJBHIHEDLNKGBPJMLDB')
# (773, 'PIGIDEIGKFDALDBKMDHA')
# (774, 'DGJPCLPHNOEBCBKACBDL')
# (775, 'HHKGMIIMJLMLDDGANABA')
# (776, 'JNMDPAKDADHMLBHPDJOK')
# (777, 'IADNGMFNBGHFHMFNCLHD')
# (778, 'ONKMCOCMJIBKONOLONKM')
# (779, 'AEMLBJBCAKFLPDJAJGHM')
# (780, 'BPKICHPJHNJCKLLDPLJK')
# (781, 'KPNAELEAMGMMHCEHFGLB')
# (782, 'BKPOPIKFNOMAMAIGAECA')
# (783, 'KMMLFDNNFNNHKLGJMAFB')
# (784, 'ADFHPLCMKJBMFLFCOJAH')
# (785, 'FPMIFAHMEPEIJLAMEEBM')
# (786, 'BMHGBNOLOMDFPKJIGPAI')
# (787, 'PDEHIMCMPOONBMOFIDBH')
# (788, 'KDGKKCOBPNPDMOHAPJAL')
# (789, 'LLCPJAPKPGNKDKPGCDNE')
# (790, 'CPDCEPOJAAPEEHLBLBLG')
# (791, 'JPDOKALAADNDIOEMBLJL')
# (792, 'BIBNMMGBENAEEAPODMBD')
# (793, 'GIPHMNIOBGJKHBBCPJLM')
# (794, 'MNIJOJMMKCNJNFDILLIC')
# (795, 'FDBKEPPNHJMNKEACFOJA')
# (796, 'NFKIADMCKDIFAEEFEPJJ')
# (797, 'CONCMCLFOOGINHBIFBGN')
# (798, 'FDIILHIIHGHLFJEKFEJA')
# (799, 'KBDEBEOOGBDNMIEPGMCA')
# (800, 'KJBBKDHDKCJIOPDPMCKN')
# (801, 'MGDKBCBMFEGIIKPCJFDK')
# (802, 'FKJOINEEKPOENAPLCBFF')
# (803, 'BPMHLLGDLKOPLFKNECHC')
# (804, 'IJCGBBLCCAHCINPKFOFP')
# (805, 'JINPHFNPPHLIEPAHLJKE')
# (806, 'EDOGDPCGKDMCIJPOPFCA')
# (807, 'CNOLHOHFGHMKDMFPMELP')
# (808, 'AHJCJLNOOFHDMIPPCADG')
# (809, 'OLIPOJPOPPAGALFBDJMM')
# (810, 'DJKEHHKMGBMBNMMJCENO')
# (811, 'GEAALOEHDEICBKBIBEOM')
# (812, 'BAIGNPCHMILBKHDICEEH')
# (813, 'CPMGHFOPEBOKKJOMJGGI')
# (814, 'AKOHJOKMCKNMDPLNGBPL')
# (815, 'LDOPPAEIBOJCBFJFIOID')
# (816, 'HGNADOBLFGGECPCECNMH')
# (817, 'EFKAOKLGNEJDCCNKDCKH')
# (818, 'LKEIFJPJBDBKCLDIHGKH')
# (819, 'LKDIFMJIHKNAGIBPEIKL')
# (820, 'EFDCAHJPKHCMJCOMFBOC')
# (821, 'AMEEPPMDDGBOECHEMMLA')
# (822, 'OELEPPHEJCJEPIHKNKEO')
# (823, 'KKNOODCJGHHNBALHKBND')
# (824, 'BBPAENKMIODAPPEGIIFD')
# (825, 'CFFPOCCLJIKFLLAJBPBA')
# (826, 'NDOKJPMHBAIMCJCJGIHK')
# (827, 'JIKLCFFNKJEIOCFEPBDE')
# (828, 'JDICPOOIAMPFELGMLMFE')
# (829, 'HMLMMOMMPEJOJDNLBMHI')
# (830, 'PPDEOFFJNPPPAMLENDJG')
# (831, 'GDMEAFLNGMFHCJJCEAHP')
# (832, 'MKEOCMPNKFDBAGJLBLDH')
# (833, 'HKMNMHOLABOAIFGLADHO')
# (834, 'BAINBAJAIFNHCDFPLJNL')
# (835, 'GFDGAOMIHEIODFKPBPFA')
# (836, 'NKEFGBBDKJPBIIFAOCIA')
# (837, 'OGIONIFHJBLNAGGMGANB')
# (838, 'MIPCHGNEIEPJCPGCIHGG')
# (839, 'IGIKOFIDFNBDMACFDIEI')
# (840, 'ECANEFOOHHLNJMBDOCAN')
# (841, 'NGMAODDPKDIIJFLFAKGN')
# (842, 'OOLMBNNPBKCPJJGENPLI')
# (843, 'IBOMKCFKKGMNCFCECOOD')
# (844, 'GHIGFAIBJGGPPMEDPKLJ')
# (845, 'DEJLKKGKFNBLAEAIOJGL')
# (846, 'AGLIGEIHPPDBHILODONH')
# (847, 'BLFJCDEIDEGKBFFCBBGK')
# (848, 'NHBCDGHPNJILNPKEHGML')
# (849, 'AOOAGEKFPIAGALBODOOH')
# (850, 'HEFGGCBFCPKGLDHDIMNG')
# (851, 'BMALPPBOOBFHLFEJNHBJ')
# (852, 'KGBKJKFHLMIMIINLNCNC')
# (853, 'MFAMJECCNIIBILMJAHBH')
# (854, 'KCCAFHELAAOPNBBKEMCM')
# (855, 'AHOEJHCDLIBAOJAKPCMN')
# (856, 'GNJBCDFOBNADKLCKLBGN')
# (857, 'MBFHLKLFIDDNKKGDGNMG')
# (858, 'JOFOKFIKHHGIODFNNDMJ')
# (859, 'HLCAIMMKMFHCGEFJNPIH')
# (860, 'LOMMAFFJDGDHNEGHJDBA')
# (861, 'EBCIOAJPNCNLHEOHGOHK')
# (862, 'BHGGAGPHHKDPBPMHGBDL')
# (863, 'HFOFIKLJJNAKBDDLDLBJ')
# (864, 'HAAOGPPEGMNMOCNEFMJN')
# (865, 'BBBPLAPAEBHDHDBGJBMH')
# (866, 'NDECMFDJCKFKPLJCPKMK')
# (867, 'PKMBMIBDOEKLMJDALHKJ')
# (868, 'HGPNHAFEOMMBNCDCGILJ')
# (869, 'FEFHFMOHGAKCNCGKEDNP')
# (870, 'EGCAOJBFJKIHPBPHDADF')
# (871, 'KFOEMGBIGGFBINOIMJPH')
# (872, 'EJGMKMMPMFANLKCMHDBK')
# (873, 'IHCCMGJNEOPFLNMAFAPA')
# (874, 'PBMBPGKBNIILEBNLLBCD')
# (875, 'GJAMGIHOGDAPJNKABNFB')
# (876, 'DMMENELJNOJICMAPFDPN')
# (877, 'FBHFEDJGAHDKDLNKLGPK')
# (878, 'BMMLBEJMMJLMABBJAFHO')
# (879, 'KCNDPKFJKPBBILHHABBD')
# (880, 'MMPDABAGPGCLPMEMIIMA')
# (881, 'DDGOBNFHBOHHLLHCLACO')
# (882, 'MFKGEJCOHAFJJLAABJJH')
# (883, 'FJGCALKIBMGGPPJHPJGH')
# (884, 'HJHBODHHDPMFMFGHOHIM')
# (885, 'PEDJDGDBFOPIIENDOAMC')
# (886, 'PFPLEKOEFNMFLFKCHOKK')
# (887, 'AIAOOIBNBJCIPPMNJACO')
# (888, 'GAIFNJOMKDODKJPNNMLG')
# (889, 'DGFNCDJGCJMHAHNMIDCL')
# (890, 'GOEJFDMFGGNLDIJNPEHC')
# (891, 'EGEKBHCINMHPMCLLAELK')
# (892, 'MCLAEFNHCENNAJGFOKHE')
# (893, 'PGHGPBELCGKNGLOKMFIK')
# (894, 'JAHPFMLDDIANJHGJJEHM')
# (895, 'EJPPFPHCGDEBAHEACIBO')
# (896, 'FPGDCKMGPLDAKLAOMJIJ')
# (897, 'JHOCMNIBAOCMJEIFPFGI')
# (898, 'MNDBODHBCAKNMDKBEILM')
# (899, 'EEFPEKJDJDKHGJBACOBL')
# (900, 'PHPELGEEFDKFJJPDEAAK')
# (901, 'NAFEGDIGOKDNHOJOMAFG')
# (902, 'BDIGKBDFGBNPGCOKOFAO')
# (903, 'EAGNKPFOKGDFJLNBDMIL')
# (904, 'CJEHBMOEMELEJIOLGGLA')
# (905, 'FBODIJLMHJOOEMGCAAPD')
# (906, 'MEDGBOCDBPKLMEFFLFDA')
# (907, 'JBCEIAMFDEAPOCMAIGED')
# (908, 'JPIJGEDILCNGBGELDAFA')
# (909, 'JOKMAGOHNPGJOGPKIPMH')
# (910, 'NHBOBKNOGGIAOAKNHGCM')
# (911, 'DPFAFBAJJNMHMAEENGCM')
# (912, 'DGODCKJDMCLOGKJNPBKM')
# (913, 'DGDIKGBFMOLMIAINBOKG')
# (914, 'GGODIIDMEIDKIFAAMGOO')
# (915, 'EJOMGHHHOELIEFIGCBAE')
# (916, 'GJBKJDEENODLAIGILJDH')
# (917, 'IKBMOPDBNCFOPFBDKNMJ')
# (918, 'BOPGGIOLCCNGOKPLHKBK')
# (919, 'POJCDLDABPOFODINBGCL')
# (920, 'JBGIKJILPHNFDFEGHAFB')
# (921, 'LBKOHNPBBHNLGKJGCKMP')
# (922, 'BMCOLLJKKOKNGFIMMAJO')
# (923, 'LKBFDCEBDPEBGOAFIMJM')
# (924, 'CNGCGACAMBNLIGNDOMME')
# (925, 'KACJFLNFGGLKHBLNMAPP')
# (926, 'OGFMLPBOPBKLJIPMCCNL')
# (927, 'LKIBMNIBBKFKEHNJPEBA')
# (928, 'JOPAIKIFHNANBDDIAPNE')
# (929, 'INMJIADENJMMCPEPPHCG')
# (930, 'ENDHKGAEKFMDOCBHLOLO')
# (931, 'NPMPNFPEHFGJKMJGIFDE')
# (932, 'NGIEGOLLPLDIJBDDALCH')
# (933, 'LFKLDAIGEOGKDEABOBCG')
# (934, 'LKHPMHHOCDCFPFLCIMGL')
# (935, 'HJNHNCMAODJMOJEBGBIN')
# (936, 'PEGBBELNDOLKCICDEOPA')
# (937, 'AIMOGPMBHPMBIDHNDBCK')
# (938, 'AIDHJBBPJOCLCDBEDAPO')
# (939, 'GAPHOGNMDOCKICONGCJN')
# (940, 'HKAJFLMKLHBFJNFIPODP')
# (941, 'NJIEIKLBDAGBDAEHEMLP')
# (942, 'HEKJKHHPOBOPGPLEKBEM')
# (943, 'MFMGIOOBGHABCLPPBENO')
# (944, 'NJDGAFOIBIKJOLEODBNE')
# (945, 'ANGDMFNJHJMLNPBOPJOO')
# (946, 'EOICEPNLMPCEPIDKCIKP')
# (947, 'OMAPCAGOLCLGIGINBIKK')
# (948, 'LJECABIEHFBMDBJIOFHL')
# (949, 'OGPELKPIHACFDFLOMOOL')
# (950, 'GBMIGFADACHHGDNILAPH')
# (951, 'NABNOGGHNLGNPDPEGPNF')
# (952, 'CHBBLJHFDMIFKICJJNNJ')
# (953, 'POEHOLGPAPHLEOCEBHEG')
# (954, 'BLHBBMOEHHGNIPBFCBKM')
# (955, 'IIJCIMHGJEMNENKNCCPC')
# (956, 'EEDBGBJDKBFJBCKLFNKC')
# (957, 'JIEHCPLIDFMJMMECHHPO')
# (958, 'EAKDCMCBJPHBNPLCPCDO')
# (959, 'EADCEOOKNHJPNGAKOAAD')
# (960, 'IIOJHPIMEKBALFDFJPCE')
# (961, 'FBOGJKEALCLFJGLBNOFJ')
# (962, 'KIPCEDOPFMEDEHDPOLFB')
# (963, 'FNDEMLKPILEIHBNJMKOG')
# (964, 'GGNIHMILMFHAGHFCNOMI')
# (965, 'IMDBCPOGGFMBDIAJHBDJ')
# (966, 'EOHOAEDNLHJFJLLPOCAI')
# (967, 'GPKJEIHMGDKMJDAGGDCG')
# (968, 'DAAKMODKDANLAKLKNOAE')
# (969, 'OIIKPNFDNOAKNFFACOLP')
# (970, 'OLJAJJEGEEBPKEKMHCLJ')
# (971, 'AKEPONAACNKJAJFGOKPI')
# (972, 'JCPHPIDIEFDPPBCLEBCP')
# (973, 'FMLPJHNENOGPOCCIOEJC')
# (974, 'FJDOCDOAOKCFMMAMBPCJ')
# (975, 'CKHNEOCEODDHLDBDCHMG')
# (976, 'EKLIODMNOHDOEAKAILLH')
# (977, 'PJLHEFGPHOGEIJENNNIA')
# (978, 'PCAKGIIILOCENIMIHLLC')
# (979, 'APHBNDBBFPBLKBLIKAKF')
# (980, 'JFIKDLMEBCNPGPJIEOIP')
# (981, 'FGEMMFMJOJCKFHKCEDNJ')
# (982, 'GPOEICICNPKLJPONDBLO')
# (983, 'NMIMONJAJBFPCNHOKJLN')
# (984, 'LHIOGLHBLMJANAHJKIHK')
# (985, 'HMFFNHCNFDDAOHLHFFKB')
# (986, 'CNMIJMADNCLHLOCKMGID')
# (987, 'MHEANLBLHCGEGAEAHJFA')
# (988, 'NIOGAMFJFNDNOOKJCABF')
# (989, 'PJHNCBKKDMIAAOAJBJAH')
# (990, 'LFLNDHNNPJPPMGPNKGHK')
# (991, 'MNCCIILBJNNJAMKIMDEH')
# (992, 'JJPDPCKFLIJPHILMMBDE')
# (993, 'FOAPPJABMMCNPMLEKBCG')
# (994, 'DLCLMHMKEBGLOIMOELNJ')
# (995, 'IBGNJCEIJOHLIPMPLGEP')
# (996, 'KJCKBNANLIHCDDFJGECO')
# (997, 'CJLFLHOMFIHMLFHLGNML')
# (998, 'EACHHHJLMPCLOKKCNNPM')
# (999, 'JAEFMCJICNAOCPCNFHPL')
# (1000, 'BLDENDOKONEPAGFHBOJC')
# (1001, 'HIACJMFHGLIBMJJJEMGN')
# (1002, 'ECEKHDECCNIKNLBCABBF')
# (1003, 'BAJHBHPCBNFGCNLNPLDE')
# (1004, 'NONMMLDADPHCKNIMDGIF')
# (1005, 'CCGPNKINAMJBIKKJJIIM')
# (1006, 'KKMDPFGCAJKOEHCANOCJ')
# (1007, 'JDMCHGANJDCPPEBMAADC')
# (1008, 'ANJHCGELCCBKAAKBMMEB')
# (1009, 'KIHDBAABPPKHMPIAHFFE')
# (1010, 'BLMMKMIMJNNNCAIKNOBI')
# (1011, 'KHCMAJLMKJAOGFACELDN')
# (1012, 'ACCKLGJJAONDDDKNNICD')
# (1013, 'LKIHMGGEBCJMCLOJABNE')
# (1014, 'OCGBODCHKKPNOMHNNHFM')
# (1015, 'IJHOEBLOLPECAEBJENDC')
# (1016, 'GFPDBJHLDLFPPGNILKEN')
# (1017, 'LGFPMLAKNINFGEGLFNOG')
# (1018, 'IHHNMEFPKDGJJOBKJMMA')
# (1019, 'FCHOKDKFJJEFPGHJAFEB')
# (1020, 'GJHLCEFCICGKPHIKNMLG')
# (1021, 'MIFCIOIFBBAEGMPANKFA')
# (1022, 'FIAFLIPGOIGNKDCHEBKE')
# (1023, 'KHEDIBCBBBCEGEHIIDPK')
# (1024, 'HNPDCMNOJCGNCHCPFJBO')
# (1025, 'OLAEKACBNKOBKLCIBEMM')
# (1026, 'ELELANHBPEFMEILPECDC')
# (1027, 'IOMAFCCPKCLJABDLLILE')
# (1028, 'IBLJBNAINCIEAAHIDIDO')
# (1029, 'BCENHPACIGFCBKEFKJFL')
# (1030, 'GMBFGLPECMMHHMGPJOBJ')
# (1031, 'PIDJLGGGCOHAJDGJAMCK')
# (1032, 'PNBLFCEKLFPEJKGMBJBC')
# (1033, 'OBJBJHOOJKCHDLCFHLEM')
# (1034, 'PLAOPNFMILFNBFNCGLKG')
# (1035, 'NGLOEGCDNDLBJMBNBPFA')
# (1036, 'LLOJPNCBHIBGODMNAJHN')
# (1037, 'HCDHDOMEFLGOMFAJFOKN')
# (1038, 'ONDDCGEHMCICBPAJNMOH')
# (1039, 'FHPIFMGPFCOPMAFNGOIM')
# (1040, 'LAHPMPFKIBEOPLBNLFGF')
# (1041, 'OHCLJNGFOOOCKDGNKPOG')
# (1042, 'BICDCNPDLABHDOHBNONK')
# (1043, 'NJOBAFFNEOGBNHOFMNNN')
# (1044, 'DLBHLLGKCLFIHOBPBMOI')
# (1045, 'JJAOEEHIMNENDDICDKIC')
# (1046, 'HJBEILPKIJFOPNLIOAPI')
# (1047, 'OEAFJKAOKBHHMKOBJCCP')
# (1048, 'ADFOEOEOCFNMGDLOAAAJ')
# (1049, 'EFEHEGBLPBNIAAOOFABJ')
# (1050, 'OOPHAKHBJHGNHNEJJJLE')
# (1051, 'LKIBKACHNMODMEPLPLOF')
# (1052, 'AOIOBPHIHHCGOBPINOIM')
# (1053, 'JKKIIFCELADBCNCNCOEJ')
# (1054, 'BCADGODGJHFKCENHLOGO')
# (1055, 'GFEMIDNAJFLDIOCHEIFK')
# (1056, 'AOKPCMNJPCLGINMAJDCF')
# (1057, 'JGCHFEMHBJOIHDJMDMHM')
# (1058, 'BOBLBLKAOLDBNIMFJKHD')
# (1059, 'CEPPKLEBPDJGLJFNFOEM')
# (1060, 'FMPILOIJHCOFCDPDAFPF')
# (1061, 'EPCGCOGHFOCLDNIAEHLJ')
# (1062, 'GFLBLMKGBKEMJAPFEGEF')
# (1063, 'MDHHKCAKHFJLJAHJAHJJ')
# (1064, 'DJEEMCNNHAECOCPKAJHM')
# (1065, 'HLAFCFHLILNKHNAEFEHL')
# (1066, 'BGJHFHENPLKLFBCEIEBL')
# (1067, 'BFJGPFIHILMEDKHLKGAG')
# (1068, 'PBFALECLIFIGAIGOFALB')
# (1069, 'FGEPAKBFDHICLBIAOFKB')
# (1070, 'FHIPPILGMFGLKNHLMMPC')
# (1071, 'AJEMFCAAPDLMLJKAMIHG')
# (1072, 'MODPBCJKIIGCMCLMOGDG')
# (1073, 'DLFBJDBBEOPHHOFJGDJI')
# (1074, 'KBFDFNKBGCBBDGKGJKKB')
# (1075, 'FJKOAGJFODKBMMLDLFNC')
# (1076, 'EKKNBBIDCCJKJNJFGAFI')
# (1077, 'OBENLPDGNHCKHHNDLAKC')
# (1078, 'JLMKBLNOICEMDOPPJIPE')
# (1079, 'DFMNMEIPKILNNMECNICJ')
# (1080, 'OMJAAIAIOEKIHOHEKMDJ')
# (1081, 'EOKINABNBPFIPOKDHOLN')
# (1082, 'CHJIMLKKABONCBFPDJDG')
# (1083, 'MOOKIDBLCDNPIAFGGMDJ')
# (1084, 'LHGJJDLAKOHACGBDJBLB')
# (1085, 'FAJKEPCNLPDJAJEDMNLE')
# (1086, 'NHMGPPKODGHDDGLANDNJ')
# (1087, 'BKJDDNBFBMBMMKGNNHGJ')
# (1088, 'AJPNKCBGKLPGBGODLAIG')
# (1089, 'POBNHMGJCJJJJCGAEMBE')
# (1090, 'HCHCFPFAGNFPNFFBFAMD')
# (1091, 'MOJGMKPKENAJGEHLIOBJ')
# (1092, 'MOGIDLINKGJNOJOBPPIB')
# (1093, 'KFJKKFGGNHPOMHNEDOND')
# (1094, 'AOCDMDOMGHANJLHLAHAJ')
# (1095, 'KNJLOAGANBFHDAKAEPNN')
# (1096, 'LPBCIAGFJCKHEFPMCKMF')
# (1097, 'GKJDFHJDHNJODNOLILDD')
# (1098, 'KKDJDCKINNHEDMFJOAPO')
# (1099, 'CHAMMBFDILMBNABHLMAE')
# (1100, 'KGJCGIMELGLAIBIDJGJE')
# (1101, 'CAKMDIPIHGJBJCAHFLAN')
# (1102, 'EKOPGOHONFJMBILHFHBF')
# (1103, 'ICALBDAHOCFGGDAIAOJD')
# (1104, 'DPCBDMODOBMPIGHOKIJF')
# (1105, 'GFHHDIBHHFLBHKLIJBDD')
# (1106, 'NOCIKDCJJFPKDIPAKHOD')
# (1107, 'JMEDHHLHEIFHMONAGLHE')
# (1108, 'HALJALJACDBEGCJPMCNA')
# (1109, 'KMCAGCNEELKABKOICLLL')
# (1110, 'HHCBKEINNKALLEFHPKHI')
# (1111, 'OONGJLDKAJANAIAJKBOK')
# (1112, 'JNEOAHNFDJLDOFNMKHLD')
# (1113, 'HMCMCPDJDPPKBHCIEIDP')
# (1114, 'OEDPAPLMBGDCLAAEDLFG')
# (1115, 'NAGOGDMANPMBNPGCILJJ')
# (1116, 'PPJJICGLCFIOIOGBBLCH')
# (1117, 'NEKNBFPMBJMOOAKHKBJE')
# (1118, 'KHLFMADADEGBEKBKMFNG')
# (1119, 'EEGDIBEALJGOMJBOAGLF')
# (1120, 'BJCLDHCKPFAMBIGNIBPE')
# (1121, 'POIDCEPOEPPBKIEFKMPB')
# (1122, 'MJNBGNOIDIILGFCEABCM')
# (1123, 'NCIOMNJJJLKNPEAIHCIB')
# (1124, 'DMBDAMENLIBLDDGIBBID')
# (1125, 'BBBGHOGDIDGOPHFJFMNN')
# (1126, 'PCEMCPDBINPFFCGLOKEC')
# (1127, 'PCPAGBEINLLOGCNKEOIP')
# (1128, 'NAAFGNENGOEGNFIBACKH')
# (1129, 'KNNCBBIEAKGCOPACMKMG')
# (1130, 'CNDNHPCCGAHGJEMGEENE')
# (1131, 'BKFPPEMIFGCJBKCHNBGJ')
# (1132, 'DEICOKBBEOJFBIOCLJMN')
# (1133, 'HOCMLPDENLFNKJKHFIPP')
# (1134, 'KHEFOAKKMAHLKIHAODCD')
# (1135, 'JDCBKBGGOEMGKDFJOOEM')
# (1136, 'EBKDONOMJABDCDAGAOIO')
# (1137, 'AFJPPFHPBFCDADNNDIDJ')
# (1138, 'BGDNGDJADCJJNMIKAEKI')
# (1139, 'BHCCKGBKMOPCEOICBBPE')
# (1140, 'MBOEDDDPNFCPEMNKKPOL')
# (1141, 'EDIOBFNFBMLBHBEOPKJE')
# (1142, 'KIKEOOPIAIKIKFDKPAOH')
# (1143, 'GFCLGGELLPCDJMEJELPG')
# (1144, 'KIJLHILHOPKJJIJDJMOL')
# (1145, 'EKNEMHJDECIABGEOENBJ')
# (1146, 'BFKJNENBBKOBGMKDEGPG')
# (1147, 'JBGFBLFNOMKODJKKBBGH')
# (1148, 'CDKJGHJEEHPHMPMHCHDK')
# (1149, 'HCLJAMGCBNDILKJGGPCN')
# (1150, 'BIODNPNFNAAANMAMGMEA')
# (1151, 'CKPNFIKJMFIFAKEJIBBI')
# (1152, 'GEGGBNDNMCGAPDDPEIIC')
# (1153, 'IIPPHNCHEMNAOFDMEEBA')
# (1154, 'NEKPCEKAHNIKOOINHPEI')
# (1155, 'IHGDGPDCCBBAHAMNDKAG')
# (1156, 'BLFPLJPCJIFFHOEMCIIK')
# (1157, 'LIACGFOEBEHPHMAKEONE')
# (1158, 'KNCFDFCEKGNJNFFGAGIA')
# (1159, 'GLKKOHCEBPCEBECPDBFO')
# (1160, 'NMNMALFAGKAEBNPLOKIG')
# (1161, 'LBGNIALAJOOILHKHKGOH')
# (1162, 'LJEOFPCLFFCGKAAHLIMD')
# (1163, 'GMHJKILFEAHGFAAPJCDK')
# (1164, 'BHLLLFDJACNPJKELEEHJ')
# (1165, 'BGNGJMEAJPJMGOFNPKIL')
# (1166, 'EDGCOEJFHMLCBBMBAGMN')
# (1167, 'BMIJCELEIIDKNEAAGJFK')
# (1168, 'NBDJNKCHIMJBHNBINKIJ')
# (1169, 'FOELFDKMNPAHOOKJOCEK')
# (1170, 'OIKACPNABDOFFDLIPOKD')
# (1171, 'CKGGLFFFCNEBOCMDBBDG')
# (1172, 'MHCNICJOMOMAGHHFJPJK')
# (1173, 'LMALFKOKCMLNLFPNHJBL')
# (1174, 'NFMOPLOMMEOIEMJGLEJG')
# (1175, 'GDEOJDIGACKOPDKCHFGN')
# (1176, 'AFEJLBOFJDIOEGIONCDK')
# (1177, 'IEEMFMPLLNNFCKIGGONC')
# (1178, 'KHNKDBPGMKOKAJFIABHP')
# (1179, 'EALLDDJPEMNLJONHBDKP')
# (1180, 'BDOOBIAKDILGKGEGFFKP')
# (1181, 'JFGGKKMMKKDNAILJNHKG')
# (1182, 'APHLEAHCCMHKGEAJJHKK')
# (1183, 'IELGKFJEJLOBEAOFJCOJ')
# (1184, 'MKIIGFIKIDKHFKNDDDCH')
# (1185, 'BNGBLCDLKGEGDPAKFJLL')
# (1186, 'CEOEKCCMFDADJFHOLDDA')
# (1187, 'KPFDBKBGAIKLDMPKKKPA')
# (1188, 'LCJIHNNELPELLKPKFJEC')
# (1189, 'GFCDEJJEPECHJFLMACBE')
# (1190, 'IOPNFJEHFHENFGMLBCIK')
# (1191, 'ICKLCDKMILDACCJNJONI')
# (1192, 'KPMHGEFNGJAHEAPACOPG')
# (1193, 'BJHNIIIAJIMKBPBNFBPL')
# (1194, 'EADGLGCNKAHDDNFDOPBH')
# (1195, 'DCDPCAKIOKCCPOBJHCEP')
# (1196, 'GCHOGLHHPBGFCILEOEAH')
# (1197, 'JLJJADKNCKIPJFFOCNMO')
# (1198, 'OFEPHDDKPBGDDDNAOJLD')
# (1199, 'EPAFPPHMDJMGBPOKEINA')
# (1200, 'JAJPCJKLFMHJIOOFHAKG')
# (1201, 'FNKIFODPOFAOBDFHEAKB')
# (1202, 'NNGNNDNOAPHHFCLLOMBL')
# (1203, 'MFEIBFMDPNMDLLELBGLE')
# (1204, 'NAIHGMCNPHDFBEPILNAE')
# (1205, 'FEHBIILJGIHGNIGODDEC')
# (1206, 'PBNALNIGBJEMKGCOKKKL')
# (1207, 'DPNIBAAJGEMDDDNHPPMK')
# (1208, 'EOEKNGIJPLJHELIONIBD')
# (1209, 'AIAEFFNAHFNDBMBALNFA')
# (1210, 'EIFMFBMFDLEJNPHDIHKN')
# (1211, 'FJFJHEBNMAHMAJEGPBAD')
# (1212, 'IDILMGJPBNJLCLJJBNDG')
# (1213, 'EDHIMJLNOAOGLKDADMEP')
# (1214, 'ACLMHCCMPEAKKMNJHKJP')
# (1215, 'FMJHKMLGFEDBKJAMNOGK')
# (1216, 'NEPCEKLAKNOAKGMOFHPB')
# (1217, 'JLPPEBBDIJJBBIBCMIPJ')
# (1218, 'EIPJINGKDNJJMKAINNDK')
# (1219, 'IKCIMKECMJFMMCJNGOAH')
# (1220, 'NCPAAEEAAFFFLFMAKCAI')
# (1221, 'GODLPIIKHKFMHLJDPFDA')
# (1222, 'EOMKPPPOJOLKAHDPBJND')
# (1223, 'MIPNBIJPDMFJIHOAEICF')
# (1224, 'MDOJECFNEHMAHIGBGKNJ')
# (1225, 'HILBKPHAEDNJMDKJOKMK')
# (1226, 'ABICPMFJGNKGBIFMKOLF')
# (1227, 'FGJKCOILOBFLPJNJMHLH')
# (1228, 'DBOKGBHHAKDMMOLOLBLL')
# (1229, 'ECIAFNBLDOBBHPBDMHAM')
# (1230, 'IHCKEHOIFJBGLDANDHBA')
# (1231, 'EFNAEIBPFJOOOCPJDFPJ')
# (1232, 'JJHANCCEJKFDHFNDCFKG')
# (1233, 'PJGMHNODBKPEGNOJJMDE')
# (1234, 'AOGKBCIFDIIGJGENJJLB')
# (1235, 'AHJKNHKOKPFJBPEGIDJG')
# (1236, 'DFCNNIMNMNMPAFMMOPLA')
# (1237, 'KNGPKEBOJBPLCPPOAKAF')
# (1238, 'NLMAPGMGKGAFLJEBKDDO')
# (1239, 'IANPFIENMIDFBHJOELLN')
# (1240, 'ENBKEGDCACAGLDGMMAEJ')
# (1241, 'OFGPKOJOMCBINJOKOMJG')
# (1242, 'LLFDNPLOGMCBGOMENFBJ')
# (1243, 'LOPDKGBBHKGJDDGHKLHH')
# (1244, 'EAHHPKMNHOFNHLIJGCDO')
# (1245, 'DHDOFKMCGAEPFJFPJEAC')
# (1246, 'JOIBLCDNJNJLCBKBPMHN')
# (1247, 'GLKHELBMKDOGKLBCPFMB')
# (1248, 'ECOCCOGDELKFNMDKDDEA')
# (1249, 'DNFJJNPGIIOIGJOIDEKE')
# (1250, 'GDHHIEABHNPCHGCMJKOD')
# (1251, 'LFLCMCOFANAPPEBDFNLC')
# (1252, 'IEFCOAGMJAHOAIAIMFCM')
# (1253, 'PAONMBANEIAJADBLFEKP')
# (1254, 'GAIHFEHGDNMJKHIFAOGO')
# (1255, 'OKOLFMDNNGAADOCNMEHH')
# (1256, 'ILLCOGAAGMNHGFJBCEIE')
# (1257, 'MFFAGPGMHHPOGHFJPFMC')
# (1258, 'BFMLFKKLMLJPLLOEKOJN')
# (1259, 'PKFDMHDGHKIEEEPMIHLM')
# (1260, 'NBGPMDPIODGLHAOBFBEF')
# (1261, 'KJMJMEPIOLDAPJIKNGHO')
# (1262, 'NINDELFNMHOMBMDEJEAB')
# (1263, 'DJDOCIIBIIHJOFJAPAML')
# (1264, 'LCMLFGEPBGPJHBJLBMMO')
# (1265, 'DPIICEGDHNBACJEFHMHC')
# (1266, 'EONBJBGLDGGNAAPADKPE')
# (1267, 'JHEDMCKGMMCBIFBLEGAK')
# (1268, 'OHDBCBCLJNHADDEMNGDN')
# (1269, 'IIGABGBOGJJGGIPCCEGD')
# (1270, 'OHBNNAIAGABFHBKKEMAF')
# (1271, 'KFCKMJCNJNCBAFKPMMHA')
# (1272, 'ADLPPNOMLNLKNGHJNLJN')
# (1273, 'IANHNFOGJGJNMJIMGFBE')
# (1274, 'CENHDEAGMDDDCAPPHGHM')
# (1275, 'KALMACACGAENOAMMKMIN')
# (1276, 'LHHMFGOMEALCHKKMJCHC')
# (1277, 'FBGDCGJKFPLCNPMECOJD')
# (1278, 'HHLMPLODHLJAMFINPCCB')
# (1279, 'DFJNCPBMGGJFMCFKDDMM')
# (1280, 'IFLPFAIOMNBPAMDJKKJM')
# (1281, 'EFPODKJJBONFDMJGLDOL')
# (1282, 'FOBDFMBIINBGMLCKJONB')
# (1283, 'FMNPAIMNMGNFPOMBHFDN')
# (1284, 'LENHNBBNHIPBDFLIMBLH')
# (1285, 'KIBNDFMKEJFJFJBLDGCL')
# (1286, 'ACEPJPGPKEMNEIOIKDEC')
# (1287, 'DOFKCMOCPDACHIIOHNCJ')
# (1288, 'BKHKCAMGABBEKIOGMDAN')
# (1289, 'GHHLGEAHFIPNIONJBLHI')
# (1290, 'CFFFDGFGGNKEJGNOKICJ')
# (1291, 'MDJBDHOLCNFMCIMKPAKE')
# (1292, 'HIJAEPICDMLGFGCEJHGG')
# (1293, 'GEIEHGDJKBNMBFFAGAOB')
# (1294, 'OEKHONEKHOEPPMHIPLKN')
# (1295, 'BCPHJDHFLBKNOJPABPIL')
# (1296, 'POOMEEJOHEFCFGKICFNE')
# (1297, 'FPPFMPBEJEAGBBOFLFKO')
# (1298, 'MMOHELJPPCFHEMJGLFEA')
# (1299, 'GKLHFJAIEJHAFCKNFNKF')
# (1300, 'IEBHOCNIFCMOKDLHKAKB')
# (1301, 'CKMFBHPGAGCALIBHKOGA')
# (1302, 'HEHJHNODIDPGNJPDCBDB')
# (1303, 'JDKLCDDPIPBKLCECKHPL')
# (1304, 'BCMBCNNPBFJBAMIDLADJ')
# (1305, 'NEKNEEHJKOLALOBEKMLE')
# (1306, 'NOKMFPCOKEIAELGJCPKA')
# (1307, 'HBFEKIFPBMJCDHJGHDGF')
# (1308, 'PBKLNPAHAHBKIIDIMEJG')
# (1309, 'NMLGENGKIGEFGBBBLKBK')
# (1310, 'EHGNHGHCABNEIFHBMJBJ')
# (1311, 'LIHFNFKCHFFJDMMMEBKO')
# (1312, 'BBBCJMGFJFELHKEAPNPE')
# (1313, 'HHKJJOMHPPFJJCOBDHHH')
# (1314, 'EJHPHALIHJPCCEIPBOMH')
# (1315, 'DPCJGIJDCCHAHGFIGLOC')
# (1316, 'JBGOLALDFDDGNJHGJIAI')
# (1317, 'JHBHIFLOFNGAJDGGLDAK')
# (1318, 'CDDAGGAGOEGFGLAIEEMO')
# (1319, 'IOGJMHHCIEENPNJEBKOF')
# (1320, 'MDLMGKBIACOGCJCOLOCK')
# (1321, 'JFOEHAAODEFLHHOFFHAM')
# (1322, 'ABAGCPANEMCPKIHPIMIE')
# (1323, 'BENGJLNKNIHNNKNPDIDJ')
# (1324, 'FFCFAPNDNCENMPFLDJMO')
# (1325, 'JNOAJJFOEMDKBEPJBDFH')
# (1326, 'AIIMGHOCGOCDGJPAFEPO')
# (1327, 'FBAIEOJBFIDGGJOKODJP')
# (1328, 'OEBBDMLNKOFPJLGONKGI')
# (1329, 'NAMJFFHJICDJALMPEGPG')
# (1330, 'FMHIKNMGBBFNMBDKMBCJ')
# (1331, 'CIGCMMJJBGOJKFMDHMPI')
# (1332, 'ADKNNBJPCJFEMLKHEHKE')
# (1333, 'BAFEMOPKAPCJGBNBBLEP')
# (1334, 'JHEHABBKICDIFPPAPGLG')
# (1335, 'EFLPJKFJLEHLOENLOAGB')
# (1336, 'LFECGPAPEOHFAINBDDEK')
# (1337, 'OFIIMCMHPMPMOMOPCPFO')
# (1338, 'COHJLKNENKMBBNJJBLOA')
# (1339, 'EHDHKFBPLDMCKBDGBDPE')
# (1340, 'JBHFLLMNNLOMDAANJIGN')
# (1341, 'GCMJHAPIAHPNDGIJGAJC')
# (1342, 'LLDANMOBAHPAPFPAHCFA')
# (1343, 'KHMILPPIKFNHKGGABAOE')
# (1344, 'ANFAGCPBIHEJKBNFDPJG')
# (1345, 'DBDAHPIAGPNIMMFDNIMF')
# (1346, 'MCOJJAEMMFHBGGJJIKMF')
# (1347, 'LFBPOGEAOGDFFLIJPFBF')
# (1348, 'EDIIJHHGHAKGPAKCBOGJ')
# (1349, 'KIKEJJGIAFHNDJENOLPM')
# (1350, 'KPMLOIJAFAMODOPGLOLF')
# (1351, 'AGKCCEKJJJGGEJAHEOFE')
# (1352, 'DEILEBKKFFALNONAMAIN')
# (1353, 'LBLEIKINPBHKLDIIOIBG')
# (1354, 'AHGLCMNBGMKFCIGJEKGE')
# (1355, 'GJGEPOLFLPCOEBHKOKCI')
# (1356, 'EPNBJNMANKKDOJPIBOGA')
# (1357, 'AEMGIIKAMELEPJBJCEJF')
# (1358, 'KNLFNNFPIJDPIKGNCFJI')
# (1359, 'IMCIELNELDKFJLEFKIEL')
# (1360, 'FLCMNHIEEDIFHHINGPDO')
# (1361, 'IFEJACLJMCKKNGHBICOC')
# (1362, 'IPIOHJOAPENCGAJFOMPN')
# (1363, 'OKLBEADCHADBCFGFMLEI')
# (1364, 'NMGAPFBGLLEHJHKFMLIC')
# (1365, 'MDEGOEBKDINJABMOEEPK')
# (1366, 'AHCBJLJFGMAGPEGJHDAF')
# (1367, 'HKHIHNMBLFFFHDMMOOJF')
# (1368, 'AEMPFDPLNCPIHLHBOEGO')
# (1369, 'NFMLBIDBEKABNFPKBDKA')
# (1370, 'BLPLODFKGIMFMAFIFOJB')
# (1371, 'AEMLNBGMNAFMHPHOHMIA')
# (1372, 'DBCPGNEFFEOGBFJGNKBM')
# (1373, 'KMNDJFGJHMMHIFJEDJOF')
# (1374, 'ACBDEAEGCJGOOBDBNEKK')
# (1375, 'HIPDEOOIEBFJLOGMABHN')
# (1376, 'AJCJANOBGCNKGAEOCLOL')
# (1377, 'FCOJJCCPIHPMGDBGNDNO')
# (1378, 'OEJLFGFLJOAENLOMPNIP')
# (1379, 'JANALMAIDOJIHDIEAEKC')
# (1380, 'AEACLMJJJLADIKHDCONM')
# (1381, 'HGKEEELECOIIAKOJMOBL')
# (1382, 'CKKHELDEMFPJKEHBLBDE')
# (1383, 'FJHMPLCLMMLJPCFDHAFC')
# (1384, 'FFLMPIHLMBMKPLFMNNPN')
# (1385, 'CMEOIBMDHKMBICFFIAEF')
# (1386, 'BGPBFAEEJNJONCPNIDLN')
# (1387, 'OIMLCDNKKKIMHBOGGFBH')
# (1388, 'EAIPMNDLNGOKBKNJLFDA')
# (1389, 'LCIGGFAOENAOGGKEHJEE')
# (1390, 'INOCCKPLJGEFIPMPJFJJ')
# (1391, 'DKIDANBALGMNBBCMAMBN')
# (1392, 'CCGEOAKKJDANIHPMEFBA')
# (1393, 'LKGFHFFBMDKCCNJCCBGG')
# (1394, 'DCPJJJEACCILLFHOJDKM')
# (1395, 'DFHNFPCPNNMKBCFLEHOF')
# (1396, 'PCFBCECJLFNEDOHNJGIJ')
# (1397, 'DICFOGMDCKHPJIEECALB')
# (1398, 'POOJEICDIEKBEPFEAACC')
# (1399, 'GFFPDNECMDMNMNAHEAON')
# (1400, 'ECIHLNLPBAHMAGABHGKA')
# (1401, 'GDJLJFJMJFHDOMKGCODE')
# (1402, 'JKEKOLMCOEDCKNPLBKKK')
# (1403, 'NMOIPDFPAGEINEIOJMKP')
# (1404, 'HDEOLHDPDNGLJGHMJPBK')
# (1405, 'ACMDJKMCAINHGKFGOIPH')
# (1406, 'AENJFKOJAKAPLHCGCGNG')
# (1407, 'IKDJHKAHIOJNNNBOGHKI')
# (1408, 'GICJLNPJFFKGBLBHIJOI')
# (1409, 'JLOPKHKHBHKPOHMBDHNO')
# (1410, 'PAHKEKCCNAOECKBEHBOI')
# (1411, 'CJLGDIGPONJKGONLEFFO')
# (1412, 'IHAENACCPDMEBGEFICBO')
# (1413, 'IHGKOJDGKHGNPCOJBHDM')
# (1414, 'CBCMMNJACJHEDNDJEGAA')
# (1415, 'EIOLEIDBJFECDHIHJEKJ')
# (1416, 'IEOMDJDALJEFNKAACMBF')
# (1417, 'GIHCFFMJKHOONJEMFBPJ')
# (1418, 'ONEAPAFIGKMCNCIGGNPM')
# (1419, 'FELJOBGPKCLFOOMPOAFK')
# (1420, 'LBOFOCMPFIEJNDEKFODO')
# (1421, 'ALOEAJMNDIFGCLJBBDGF')
# (1422, 'JPNDALFCLGOAFIJJCNBC')
# (1423, 'NABJKFLDOCCPCMBFLLMG')
# (1424, 'JHKOOFHDPJBKANDFGDMF')
# (1425, 'FDHNJKIHBJOPKILMEFAK')
# (1426, 'FLPIBBFBHFFEBCADIMEP')
# (1427, 'GAGIGJNNFLHCHLDPILBG')
# (1428, 'ILHJAKJKAEOENCDEABMG')
# (1429, 'NGKLOPBJMBABFJOLINOF')
# (1430, 'ABNMPDPJBCGAAFMALCHC')
# (1431, 'BJDKHODLAHGAIJNLEJPM')
# (1432, 'OFHBONBBMIHLOOBKIBIC')
# (1433, 'LHELOIHPFBHLMCIJCKCI')
# (1434, 'DJPDIILOILOBHCHLBKIO')
# (1435, 'OLLHPNBBLDMAMPKFKDEK')
# (1436, 'NMDNOFMFHOIHOKIGINDA')
# (1437, 'MAGFNJLDNAAPKOAABBDB')
# (1438, 'HMOCHKBCJGNAMJDDGPIF')
# (1439, 'CPDJJAIGPAFHLPLAPPEK')
# (1440, 'KOKJKKLLBLFPFNDCNKLI')
# (1441, 'HHGIOGDOALJIPGMNHGFP')
# (1442, 'DLCCENNKLHBAADBDOMDB')
# (1443, 'FLFHKINDIMLBHBEEPOFP')
# (1444, 'EMMCHIHFKLMMBONJGNKK')
# (1445, 'BBGAFKJBMHDCJNFJPGLL')
# (1446, 'IJPCEELCCCNNKHCEOGKO')
# (1447, 'PEEMNMBIEGNEEDHEFMJG')
# (1448, 'KFPOPBLGHMLLOOPGDOAA')
# (1449, 'GNKNONDHPKJICFFHLMMB')
# (1450, 'OFNBGELOMLGBLJOBIGAJ')
# (1451, 'KCFLIPIDFMCOMPPCAOEF')
# (1452, 'OKCLHBDLNGHHAKOKGGPG')
# (1453, 'GPFPMDOJIONGFPEANABO')
# (1454, 'EGHKFBFPHBBFINDEBGCK')
# (1455, 'INHLLIFPLKAHHHJKLFBO')
# (1456, 'NCNBHHPNNKCFGKIFFHMK')
# (1457, 'CMOJCLNBCFKHBKCJLNMK')
# (1458, 'PEGPDPCOCBBOFPKFKPCN')
# (1459, 'PEPIAAAMMAMNHPFGBIMC')
# (1460, 'BGGEFPLCKCBPDGBLGGMC')
# (1461, 'PBMOKGGNMIAGCGINHADK')
# (1462, 'PIDLEBABFEAKOGDGADAA')
# (1463, 'IOCHGHDNEOJDKNJGPCMC')
# (1464, 'JGAMKKCIKNFKLGPEINDF')
# (1465, 'OOIDMJMABJBEGDILKMGP')
# (1466, 'INAGGDGNOBFGINEJDDPG')
# (1467, 'AFHALLGLFIMBJKOEHACH')
# (1468, 'JBLGDMGLHNLABFOCMLNB')
# (1469, 'GOMJBPKBJFPPGPEJKIAH')
# (1470, 'ENJAPEFCOAJGNJDINBIE')
# (1471, 'DFOMHEJOALBMPOKMMMID')
# (1472, 'JFJMFKIGBFMPIIBFIEPP')
# (1473, 'MFDANDHENDOKKPDKPLNI')
# (1474, 'COOEBHHEGLGCEKHOMLAM')
# (1475, 'EOFNLNKJNDJKJKCHNLNH')
# (1476, 'JFOEBPNALILPBHCAADGC')
# (1477, 'FOCNMJDKNIKKDENDNEHH')
# (1478, 'KOFMONAPMNGCBGJLBHDI')
# (1479, 'HDFOEKJCMGKNGJLPCOFD')
# (1480, 'MBIENICDEJKBCMPLHOAO')
# (1481, 'OKKDPNJNHACNGIGAOGHF')
# (1482, 'PHKCAONBJMFPLOFADHFG')
# (1483, 'KPEMPCJNOFJLDJGELDEA')
# (1484, 'CPHEFMKEGFMIINDHIMNN')
# (1485, 'FMKJEDDELFEMHHOBAKOG')
# (1486, 'FEBIIMEMCGFHMKHPANGM')
# (1487, 'MHGOCCMHDNILJEGMPNBB')
# (1488, 'BDODAEKAIMACJAAAPJPP')
# (1489, 'JDCJJDMMEDCFADKPJFLG')
# (1490, 'AIONGJEEAHGCGPMNOHOE')
# (1491, 'AKKMOFDIMMEOBHPFOLLC')
# (1492, 'DJAEOONBPMJJAIHHCKNA')
# (1493, 'CNIGLJPMPBJINEEHDLEA')
# (1494, 'MOMEBJJFCLFIDIFKDDNP')
# (1495, 'JEFIINGHIDPDKANFCPDG')
# (1496, 'PMBKDGCFCHKCNOGFPOGJ')
# (1497, 'HGFKKOAHNPICOIIJKHMD')
# (1498, 'BCAONGPCJLEPHCNJPCHE')
# (1499, 'MDMJJOEDEAIEFHMCPIHN')
# (1500, 'LIOMMFEIBKMOHMPDMKEK')
# (1501, 'EPFKNBCCGJCGPLFOBKAJ')
# (1502, 'IDHNAJIEHEGIOEGHJGLB')
# (1503, 'NHGDGDDDJPOLKCAJDGAD')
# (1504, 'PDJCJFFNBBJBDHFDLMPK')
# (1505, 'MFPIDAIKIFNIDKKCCOFD')
# (1506, 'NBADICKMGKCCPBHBLAGC')
# (1507, 'NMHEGJAEJOJHFNCNMPFI')
# (1508, 'LFDJKPEEAMECMJNEEOIG')
# (1509, 'JFLOEGAILHDJKJGBFHAH')
# (1510, 'MMPKEDMEIIFOHEMPEECA')
# (1511, 'FNFNFDEEFIHALANFFMPG')
# (1512, 'KOPCLNPOMAFPMLNNMMPL')
# (1513, 'DGKNLKGABPIJEINOFEEM')
# (1514, 'FBCLNILNFDPOCJHGBPKP')
# (1515, 'HFBJMCMLCPBKKHGKPHJO')
# (1516, 'KPDEBNALCCKMBKMOGDKN')
# (1517, 'JJKBIJHNNFDEDIIGEJOI')
# (1518, 'POBDEDACNLIADPJKNKKF')
# (1519, 'BGBOKKFFNMBMHLKNFBPM')
# (1520, 'DBIMOINMOFPJOCKEOFLE')
# (1521, 'BFJBJFCGOBCFBCKIJCLG')
# (1522, 'OMBHBBDEFBCDCMEDEAGJ')
# (1523, 'KNGGNMOADBAPHPPCJLAL')
# (1524, 'NEHAIBKLIIPHAEIIENKH')
# (1525, 'HJHFCBADNEIBHCAABPDB')
# (1526, 'LLKHMJNAGIJBNODLLGNL')
# (1527, 'NLDPOFDDDJCOPECODJCG')
# (1528, 'LPOKKCPOLBEBJFBPCHEI')
# (1529, 'BONANGIHFHIHMGACKEII')
# (1530, 'IFNLKJPCBOGOLJDEMIIG')
# (1531, 'NHPLBMKPCKBFNADIAJFG')
# (1532, 'NJIMAEEDKBHNGIFOLGLH')
# (1533, 'NPBCAMMJPKJPMEEOPOEM')
# (1534, 'NNBHHMGPAJIOJLDONJGP')
# (1535, 'ODHJPMJFHILAENEHOIHK')
# (1536, 'IOJKFIPHAHOACJCEPDMA')
# (1537, 'DCHPCKHDEAOAGAKIHKLB')
# (1538, 'BDMLHOFPCENEBJCCGBPK')
# (1539, 'LBBPOLJDLHODEFBHOIMG')
# (1540, 'PKKIHFMHOFDJPPLLAIGC')
# (1541, 'AGFIILFOBABOADOBCKIE')
# (1542, 'LCEODCNANCIPJEHHJJAA')
# (1543, 'MIFCJHGKDJNDABMJOICC')
# (1544, 'MDHNIJMCKODBENGDGCNP')
# (1545, 'IIJPCNPCNCGMFFFLGLHG')
# (1546, 'JAMPPAIALLANIGDFLOPF')
# (1547, 'PDJMOKPENKFJPIABHLHN')
# (1548, 'FJHFFBMMOPMIEBDFBFDC')
# (1549, 'ADDGOOBLHOCBFCKONOME')
# (1550, 'MIMCDNAOGBAPKHOFKIIO')
# (1551, 'FPOLFLLFCDILJJCIIDCN')
# (1552, 'LGKGPFJNIBENJAJJIBGK')
# (1553, 'LBOBEGGGBCKPPNBGIOPO')
# (1554, 'KHBNDHMGMNCJNFKBLAOJ')
# (1555, 'KEIAEDBAHPGFALEDOAOJ')
# (1556, 'CPJGJLGFDBJBHJFEDDHB')
# (1557, 'GIKNNMIHALGDDIDFPFML')
# (1558, 'EFNGCLHIAAMHNMAGEHPI')
# (1559, 'GMCPDEMJPGIGENBHOPND')
# (1560, 'JFKKBPOGOELKBNPJOEAL')
# (1561, 'LOOCGLMJPGPONCPFOLPJ')
# (1562, 'NHOGPPCAEIFMJKOCKJEE')
# (1563, 'DKAFGOENJAIMDPAMNNOH')
# (1564, 'LLFIHKMHCFDBPCOFDPJF')
# (1565, 'KJAEOGMIIFHPJIJAFIEB')
# (1566, 'EIGHCALJJHBFMOMKHGMK')
# (1567, 'GCJACEFKJLLNOLAMOFHD')
# (1568, 'MPAFBBJDCLIODKOODIEA')
# (1569, 'GCKOJPLPHDPCBIHGGOJE')
# (1570, 'AHCECKGGLLCMGHLPKOGB')
# (1571, 'HHCGKNNMCCILOILPCCPM')
# (1572, 'CBDMGFCMHLLGPOKANEMB')
# (1573, 'PCINKGHMCACALDOABJAO')
# (1574, 'EHNAFDAEAKJHDOIHNENN')
# (1575, 'IAFMJJJOKBBHCMIFLFML')
# (1576, 'KKDKAPGJBGJNMALNPPMK')
# (1577, 'CPNJCKMLDLAOFGCJBBLA')
# (1578, 'LBOJLCNIGFKHINGFGMGM')
# (1579, 'NJMMCPJJBOLNBPHJIJPB')
# (1580, 'CNDMJBMPAGNHPMJCGJIK')
# (1581, 'NGHDBHLBMMKDCEAMLOEC')
# (1582, 'NAPIFKBMLAIMJKNIGEJK')
# (1583, 'AFOCFCFDAPNEDMCKJDDF')
# (1584, 'KCHGABDODKBLLDDBHFIM')
# (1585, 'MNJLOHIKCHHDJIFEFIPE')
# (1586, 'ACDIMJBJEHGELCKFHJBJ')
# (1587, 'LFNHKANMLOBIOFCMEIND')
# (1588, 'MABHIOFLKGJHKOEBLHMG')
# (1589, 'OMJJLEEIKALJIEFCBAHM')
# (1590, 'JNEPNPBALJHLGMDNDFGP')
# (1591, 'DPHLBPDOEGDLOBHHIABF')
# (1592, 'HAANFMPFKHIOANEPDPKL')
# (1593, 'MMBNKBIDEPMMHCENJJPJ')
# (1594, 'NOLFMAFCHGEILCHJKIDG')
# (1595, 'LHHBIFIGBLBOCHAGOGPP')
# (1596, 'HPOMHDHHONOBDJFNJBOA')
# (1597, 'BHPBGAJOCJNOPEFKOHEL')
# (1598, 'KNGIPGCPAEHNPBGEGEDB')
# (1599, 'BDBGCPHDOOOPMLBJEGLJ')
# (1600, 'MCCCDBEICDAHPEAGNGPH')
# (1601, 'FANFEOOPOBGHEHNIFGFG')
# (1602, 'KFKHCBJNMPHBGOBNDKGE')
# (1603, 'AOHPJNIGNNHNEMCNJEOO')
# (1604, 'LNNLICBDFMNBIGJFLKKP')
# (1605, 'NFCAEHJBBGFPJJMDBHOL')
# (1606, 'PBHDJECKNLIMDHFOHAFI')
# (1607, 'AMCKINHCEBJGCNJAGPFM')
# (1608, 'NMIFAMEAHCFNFOLMAINH')
# (1609, 'OPOFKMPOALAKOMFCBKCL')
# (1610, 'FLAEALCAKGMKPGLHIBFJ')
# (1611, 'ELNOCGHDADOGHPIJLFPL')
# (1612, 'HFLKNKONJPCIJCJAKENB')
# (1613, 'AIFPMJPMKONCKJFJOLDA')
# (1614, 'EGNLGBIFMNPOCDCIKGOM')
# (1615, 'GPDLLLJINJJHNJCBFGNM')
# (1616, 'INCPOODKGHJJMLLOJKMO')
# (1617, 'ENLMFOLAABMIHBICEDOG')
# (1618, 'FKKPJGMNHOOBIDNPNCCE')
# (1619, 'JLAFFNGNNDPKBAPJPKAH')
# (1620, 'HLGLDBDCGDNLMMAHGEHL')
# (1621, 'AGBPOOJEGFFOALOHPMOA')
# (1622, 'PHMKKBEIAFCPOAOGHKHG')
# (1623, 'KIJFAMBFLCBCNOOMEHKH')
# (1624, 'EPADJEOLPFIKKMNHAIFK')
# (1625, 'KLJLIDLPHNIPBCBKOOEC')
# (1626, 'ANHEFFMNHKJJLIHOFNBB')
# (1627, 'FKIBFDMMGABDMDFAFGEE')
# (1628, 'MPIKAPHHCBCEGKCMDOCA')
# (1629, 'FHELJBJIFLIAJJMOKJHB')
# (1630, 'MMIEIMIBNGFLKJJJMFNF')
# (1631, 'EKINAOFKNFPDIFGHBFIB')
# (1632, 'ABIHNBAPMMEPBCNEFFOF')
# (1633, 'FOCMGAMGMHHBAGFPHFEB')
# (1634, 'FGOACOFCECLDGMPKCKCA')
# (1635, 'BOKAIADCNOOIFONEHINL')
# (1636, 'DNHGIMJFLAFMMPLNALDE')
# (1637, 'CKLAJGPGDPOCPCOJFPKK')
# (1638, 'MMFNIBFBIBMNHICKCAJC')
# (1639, 'HOMFGGGEECNCEFEOGPKD')
# (1640, 'FMLNOCIBPEHGFEJNICOO')
# (1641, 'HICBCDHOHJFBJLNENEIF')
# (1642, 'FAMFDDHBDPCPLFAJMFKO')
# (1643, 'AMBDIFAIEHCIBABDBPJN')
# (1644, 'OELFKDLMBGEPGCADMBAP')
# (1645, 'GPEJLOHMFGNPCHIHPLKG')
# (1646, 'GOFLALKJFCJEHIEDCJEM')
# (1647, 'CPNGHOIDODKBPKCPCJMJ')
# (1648, 'PKECDFEBNJPBDBBDBJMA')
# (1649, 'FNPHFCBKHEMJFEDGILPG')
# (1650, 'CNPLAFEPGGGDPGIFHOOJ')
# (1651, 'GOBNDLBOLLFMFJICPAFC')
# (1652, 'FCDKLBNCBPPMICMAPPJJ')
# (1653, 'GBHDLKOFMHHNGJINKCCP')
# (1654, 'GJNAEFOMOLECEBGLDIDK')
# (1655, 'CIFHCGLOLCPMFGNIGAMN')
# (1656, 'FPILDCHMDPKDJFKFKANK')
# (1657, 'OCCEPJOILONMFKNMKPPG')
# (1658, 'PDGAJDPEILMIMFPPECEJ')
# (1659, 'JFOAOCPHKKBOMJFFOAHP')
# (1660, 'KAKIFPHMAMGCCGNFMOAN')
# (1661, 'KHBPJFKKHEECBIPDIDEL')
# (1662, 'NKICNAAFLMFLKLIJADEH')
# (1663, 'LHMCAFNLNBKKKNNGJJPC')
# (1664, 'HMEDMLHOHCHFCJBMBBHO')
# (1665, 'MHJJFLGIJIDDJHBMIOIN')
# (1666, 'ONOKBJPOJJDHMJGIBNIF')
# (1667, 'EELKNDLBACHNMCIHJCCG')
# (1668, 'AAPMLHFIIODFFGCAIAHB')
# (1669, 'OHKDDMAENKPJOOILKOOE')
# (1670, 'APHBHGDMHMKNMJNNOEDO')
# (1671, 'CPBODJGAIKJLNAPJCKHF')
# (1672, 'PLBLNDKFHKAPFMGOOJOL')
# (1673, 'IDHIHBHLGFHBEBNMEKCA')
# (1674, 'HHODIFANMGGEDCMDDJBP')
# (1675, 'NMCJENJFHGBAJLMLAHBF')
# (1676, 'EOGPOLFBOIMIDEGOIICA')
# (1677, 'OHBLALCKJNHDHIPHMGOI')
# (1678, 'BLIOFIFNEOPDHFGAFNHO')
# (1679, 'BGABMKKAPECEHOGPHGKE')
# (1680, 'CBPFDIDONNKAPOJCAPNJ')
# (1681, 'BPPLBIKGBJCNFMPFPCDH')
# (1682, 'AFJLJJPGAGOBOPHFLLGG')
# (1683, 'IBONLFGBLIEEBHMKPFDK')
# (1684, 'MEEHHMKPAOOFONPMCDFO')
# (1685, 'FNKDPJMBBFIJALNPHKNE')
# (1686, 'IKGNGJANFCLAPCDJLGPF')
# (1687, 'HMHEFALMGMHJJFOFGABG')
# (1688, 'HEDLMGBDHDOILCONGICM')
# (1689, 'PFNAPMGPEBMCIGFLFGMN')
# (1690, 'NMFDFCBLIMHBDOFPLMGL')
# (1691, 'FMDEMIEGHCDNNADMLLLA')
# (1692, 'DDDCOCALEILAEILCLKHK')
# (1693, 'AAMIFPIFCOIJPBONCFJH')
# (1694, 'LMKFMCOJAGAEHMOECIPE')
# (1695, 'MJLBLGGIEPMBNGDNDDKC')
# (1696, 'NACKKLEJGKHOENJCLPEK')
# (1697, 'HKMFMBIDOGAFHPIPPDAB')
# (1698, 'FDGBDDMOKPMJECDAOMPP')
# (1699, 'HJAPGHPFCAPCBLOFGFDP')
# (1700, 'MPOKJDNFPGHNJMLHMNHB')
# (1701, 'LEIEOEDJPADDIEIEKODH')
# (1702, 'PFCDOPFNOELKMJKOLPAB')
# (1703, 'LBKJGPDGJGDJJCKNMCAA')
# (1704, 'FALLOOIDLNFHBDLOIBPF')
# (1705, 'MIDCKALDAOEOJCMIHEPI')
# (1706, 'AEFNJEHNOALHODODHHJK')
# (1707, 'JNIBLHFAOPJBEJKJELPC')
# (1708, 'MJFCNKKMEOKDDDPDGFJB')
# (1709, 'FFHEHFCPEPCHPLJHBNPN')
# (1710, 'GGJCANACABBJKNFAAJDE')
# (1711, 'PMKEFDHEPBJFGFFLMFKI')
# (1712, 'FHNNDKPHDDNOGNPOPCAB')
# (1713, 'MDBDLLDJOKFIPKHMOHIN')
# (1714, 'HLPELMNPNHMDBNHCCANO')
# (1715, 'AIGNFPPFKKNLOAPNKEFC')
# (1716, 'PFJKLOJECEDOKHFKGKCC')
# (1717, 'OPBKCCBCMFFJAMCOLBHC')
# (1718, 'GAAMGNCJEGNNMHEDBIBD')
# (1719, 'FOOMLMOJCIIILEOAJIMH')
# (1720, 'NLJCFPFDICKODIDMABNL')
# (1721, 'CGCKGFGMEIJCEPKBGAGN')
# (1722, 'OPECNBFGFGBILCBBGJLI')
# (1723, 'DFAIEKPFODEFMCFDHGIN')
# (1724, 'NMPLMGBOFAECPIHHHDKI')
# (1725, 'MGFBHACIJLNKAPAFGLLJ')
# (1726, 'EGFDPPIBEBLAPKCFPBJN')
# (1727, 'BMECAPLMAMNPIPLONAEA')
# (1728, 'BOLGGAHDKAJALFPMCBBJ')
# (1729, 'OGNKHMOMOKKHCBJCGDEP')
# (1730, 'IBEGGGELAPDKAPBIHFCC')
# (1731, 'FKKPBAFLDPGAMLKCBLLO')
# (1732, 'MCMAFBAIKEOHOKMPGFMG')
# (1733, 'INMNDNMLPCDKDCPBLPAC')
# (1734, 'AMCBLEOAIFCBEKFAIJHA')
# (1735, 'KLCAAOAECEMOAAOPONBE')
# (1736, 'HGJJPLECKFFDANEMHGDP')
# (1737, 'MLBCDODNJJFHINCNDAAJ')
# (1738, 'OBDHNFAFAHCHKAPMMKJB')
# (1739, 'MLEFIPPEMDGLHNECEHHD')
# (1740, 'IENEPBCKBBIPDICCAFBK')
# (1741, 'KOBDOBFDIKCBGDGODKCM')
# (1742, 'JJNBFHIOAEHOMCFMGDPA')
# (1743, 'JBELKIAODBOICNKIMLND')
# (1744, 'JJOMKDIOPDBNDJKALGOI')
# (1745, 'ICOHBJHNJKIMKDMAFCNP')
# (1746, 'FDKICFKNCMIBOJBPFHNK')
# (1747, 'HAIEJIDPBBHKLMGBNLDB')
# (1748, 'EPKOHOGEJFPCMNCHLCKN')
# (1749, 'IGFLJGPLEILCKBOJNCNP')
# (1750, 'JGAFJKNLEMKBPEPANPEF')
# (1751, 'LMKAMBLHGCEKEFMKLKLE')
# (1752, 'KOOIKGIDGPJIENJCBFCA')
# (1753, 'KACFFFJFHPCANFIGFIKN')
# (1754, 'EALLNKMEGPPHACPLBHGF')
# (1755, 'JLNHCAFOCKIJEAOCHOCM')
# (1756, 'HCACFLCOHLGPIGJGNFNC')
# (1757, 'NCPAIOJPMDNIGGEJDOLM')
# (1758, 'CLEPDMLHCHBONAJOIALJ')
# (1759, 'NHJPLNHPEAMLMBJOEECH')
# (1760, 'GCLAPBEPEKOFBBGKCOKO')
# (1761, 'BPFHKPJKOFFOOONHBFLI')
# (1762, 'MIOGGMPCLFAJGBEOJGNO')
# (1763, 'JHECDADKPLLEBHLOEJKH')
# (1764, 'BHNKIEAMMBMHKPHANCNE')
# (1765, 'PJMBGIICMJDJOHMBKCPG')
# (1766, 'DAOFNBMKNKINOLNBEFOD')
# (1767, 'ECJHBKIEKAMMJLCAADJM')
# (1768, 'MEDHEDKEJJMFHGEDNCHE')
# (1769, 'IMODPAJLMDKOELIPILBM')
# (1770, 'OIOOCJGMEDPFKKJLFEMP')
# (1771, 'DMNPOOPFPJBEHOCBEBPM')
# (1772, 'NKLLKOPFEOFGLKPODJKC')
# (1773, 'OLHMLFHGCGMOEICDCNGL')
# (1774, 'MKFHJNLJNKFJAGIHDLMN')
# (1775, 'KNIMDHDCPIPPJDOCEAIC')
# (1776, 'AAOCGKKBOBDCFGEEOEFO')
# (1777, 'PDONEKEDCBFMGNABMEOJ')
# (1778, 'IENNCAKAECLDALJEJKDJ')
# (1779, 'MHNHBJLGFGGGLDFKJHNH')
# (1780, 'IGIGLKDLAGOFBFKBJPLN')
# (1781, 'HKAIBPDKKKMKEENLMJKK')
# (1782, 'POMNDPDJINCBIBDDOMGD')
# (1783, 'AIBMLADOHPCJPMEJAGAH')
# (1784, 'IIFKHDKLDHPILFIFJHEH')
# (1785, 'JHNOLGCLGNJBCGDHNCMF')
# (1786, 'FGIHAFIPFLPNKCBAMHFA')
# (1787, 'NCOPOGIICFNILFCIFPOA')
# (1788, 'GAOCJHFLMLIEOEFDHGAD')
# (1789, 'MHPBAGEPLKKDBKIOMJHN')
# (1790, 'BECLCDIAHPODCJPLEPPB')
# (1791, 'EKDBOLANBELGHBDLAGLD')
# (1792, 'JBHHKOMNCNILHOPBHKOG')
# (1793, 'ELBBGHHLABGCHCNBBBID')
# (1794, 'DDOKAOEHMDLBBBDNEHAL')
# (1795, 'OLGACNFCNPHIHCEBHDGL')
# (1796, 'GPHAIHGAAIDKHHIPFGOP')
# (1797, 'EIHNBKNIEIEJLDBKPJKG')
# (1798, 'OFCGNLCMGEHLJGCPFLKH')
# (1799, 'NABKCPFDJGDDCBBPJFGL')
# (1800, 'EBFAAIAIFCEFCKGDAEMK')
# (1801, 'BNEBAGFOPLBACFDKFDDP')
# (1802, 'DBCGBJNEKIBMCKFDLHKG')
# (1803, 'DENHPPPOMNKPFDONEPFM')
# (1804, 'CFGFGJOJCNPJIJCEPDAN')
# (1805, 'FJIAJEHKFNAIDDOBPLFG')
# (1806, 'LKKBNPKBIOIOFKMNNIMA')
# (1807, 'IGABOLANLHDNBLOPPDHF')
# (1808, 'IENOPEENPIBDLNHNLHJB')
# (1809, 'ELKIGGPNJFGPDEMAGMNK')
# (1810, 'DNDEDEHLJCHKIBHKNAAI')
# (1811, 'OAMMNDGHHCHDEKMOMCNA')
# (1812, 'COHFHGFHFKADBJHJPMAF')
# (1813, 'MLGAMEFMKAJKGMAILLID')
# (1814, 'DCBBOLCEJDEBBGOBKGOK')
# (1815, 'MNHMNANFBHNNJFJGJNEG')
# (1816, 'OBKBNIEKJIPBDGGDFPHD')
# (1817, 'CIPFEHCPLHKDCGPMDKAH')
# (1818, 'FIAHBBGCLOGLPLOMCKON')
# (1819, 'COJMJCEOAGFCNJENJDBI')
# (1820, 'LPEKIBGOGEEMDAMNKGJM')
# (1821, 'DJPJLOAKOKANMPKKGBEM')
# (1822, 'EIFIFMCEJMMLIOMCLNHD')
# (1823, 'FEJLMFDFKFAPOILDAKOA')
# (1824, 'PJGAHEDPCCGMHAKIKLBH')
# (1825, 'FKHKMKBBDAIBIIDAILOH')
# (1826, 'OCKJBCJNLBAEKDNANOPD')
# (1827, 'GDJPECFDJKOOOCOEGGPJ')
# (1828, 'LJJHKMMLNGHALGOBNJMD')
# (1829, 'JHHDPIIHHAFIPEDPLOGP')
# (1830, 'KLHGFGCMFPCJINLHMNDI')
# (1831, 'MDFEDFPDMLPGNCBJKALD')
# (1832, 'HFGEOONJCJFMEJCNOOEI')
# (1833, 'IDFIHEFLJGINIAEFCBCE')
# (1834, 'KNBJPLAFHPIHMABKGLAM')
# (1835, 'GBBEIIGGCAAPBHFIKKAD')
# (1836, 'KHOFBCMOIKBMEPMBAPBH')
# (1837, 'HDCACENOGLIPOIKHEKPA')
# (1838, 'GOJJLJAMNDCFEGJCCFCH')
# (1839, 'OANAPGCLAIBIHMANJDAH')
# (1840, 'MDBHDPMNINKGODLBAACC')
# (1841, 'HGHOKHOMOJLDILNADLMM')
# (1842, 'PAPFNDHHOJMEKOKHDEGP')
# (1843, 'LGEHEFHFGNBIIFJMNNJH')
# (1844, 'JHIPHMPJNOJKCLKLBNGL')
# (1845, 'CLNADMADLLGGBGKJKNAB')
# (1846, 'BCPPOFOIAJGJEFNCMGIC')
# (1847, 'GPEJOONGGHBKKKGOEDDA')
# (1848, 'OPFCLCHLFJAHGJDLIKIO')
# (1849, 'LDEAPJPDEPPONLPONPNC')
# (1850, 'EJANEIDLCILFIIOPPEOH')
# (1851, 'EPLJMCDHNHEMIIPALFKH')
# (1852, 'MJDEAOHDHIFAEPOCHOFL')
# (1853, 'MADEDAIILAKKHCOMMMOG')
# (1854, 'ECKIMLGHHJOEIEEJANFB')
# (1855, 'JIMDAIJHMOCPGMFADODP')
# (1856, 'CBDJHKBJAEDMAMICDGAA')
# (1857, 'FPNPEILDIOPNCEMKFGHN')
# (1858, 'FGCCIDPAGBJOOKADGJMG')
# (1859, 'EJHDKEEIJLHAOKFHIIMB')
# (1860, 'ABFKAEMPONJOEDGKFMMG')
# (1861, 'BBLACBFEFAFNBOFEMINO')
# (1862, 'HDJIKLHNAJOELPKEEFCI')
# (1863, 'MPKKGDEICBEKBHBNNHJO')
# (1864, 'PCNOBJJJCLGBGONDNJHM')
# (1865, 'DFBCOPCBICNGDBILLJGI')
# (1866, 'AADPHKBBFENIMNIJNHIA')
# (1867, 'JMCDGOMODKGPHPJDHFAL')
# (1868, 'ONIAJINLLFANDLHFPOEM')
# (1869, 'CJBBEMLEFDJEDADPMEDB')
# (1870, 'ICFKABPOEEEINKPFPGAE')
# (1871, 'PFAOCNGOENIKNOOBEOGA')
# (1872, 'DDBPHHGJFGKKJPFNPMLP')
# (1873, 'BBODPABLHAINCJLPHDKK')
# (1874, 'POGDEIMFEIKHDGHGCBPO')
# (1875, 'DNMEHKNMBAIOBCHCGOGF')
# (1876, 'FAHDMHBLJOCHBNCBFJCE')
# (1877, 'GDKEHECIPHLFJPGBEBBJ')
# (1878, 'BHMIMLLIMPBFHOCFBOAG')
# (1879, 'EOJPKHMHIFJONLBHIDGF')
# (1880, 'HCJONIPHAOKJLGPCAEFJ')
# (1881, 'POACAJOHIGPEFALMFADP')
# (1882, 'KKKNFLMCEMONKOAJIOIK')
# (1883, 'PPPKMFBMGACKDPENONDA')
# (1884, 'PJFFAJJABKDHPFCHGLFB')
# (1885, 'BIFJNLACONHLDCHAPKAP')
# (1886, 'ODEGCILMDFBGFJKDHPIF')
# (1887, 'DEDEIPFEHEKHJOBICFIF')
# (1888, 'PHPNBPJBCFBHBGBHFFEI')
# (1889, 'KOBELOBOLLFKCPOKJOCP')
# (1890, 'GHPILNBFEHJKPMLALFDO')
# (1891, 'FKDCHJIKKJJMLFBOLFOK')
# (1892, 'GOEBNDMPHCGDNKCJMPMM')
# (1893, 'NODONLKNOGLIFFGOFPCK')
# (1894, 'DLHKECDNOMJJKBCICAIM')
# (1895, 'IKGBBLDHEIOOMFBGLELN')
# (1896, 'MKMOEGHMFLAMMMPBIBHG')
# (1897, 'KGDBAGCLLLEIDDNFGKKA')
# (1898, 'JILMEKGLDGKMLEPFEOIB')
# (1899, 'LDNLOLOHFPDDNMLGOOFB')
# (1900, 'BPMBKCPLEHMFELNOFJJE')
# (1901, 'OHAHJCMGEDHIGCMCHAKE')
# (1902, 'GGFFEHGMMBJCNGBBPLFK')
# (1903, 'OLCDMPMKBHOOGJKEILDG')
# (1904, 'AHFCEFJJJNOEJCHBCHHL')
# (1905, 'PJHMGCOKNMKCNEHAAKNG')
# (1906, 'IGHOKPLPECGIIEJGOFGC')
# (1907, 'JJPGJNICIONKJNEILEMD')
# (1908, 'OJGBMLHFGGEFMCEDMCJA')
# (1909, 'PFCGFDLJMANOEAOFGHGE')
# (1910, 'BMKLKLHEAGCFLCCDEAHL')
# (1911, 'AKFCMLGDAJMIBKGFEDGJ')
# (1912, 'HNMLDMJDIJNAICDIEDKN')
# (1913, 'OCKOPMGJIOMLPFMCCHMN')
# (1914, 'GPFPGCOKHNOGGDFKLOGN')
# (1915, 'GMEHIAEDLLHAPPOGIICP')
# (1916, 'AANGNKJIMMCJJOIKMGNK')
# (1917, 'JPHEJJNLGLALLLADGLDB')
# (1918, 'BDFGGHPALFGHJDMDEJEC')
# (1919, 'NNNGCPDMEMGCDNIEHJOI')
# (1920, 'LDMADDIFINLPECGAFKNP')
# (1921, 'NAFLPMBINKFAGBIODHHI')
# (1922, 'KPBODFJBLNOHADKNKPAF')
# (1923, 'KEAAOPGFDDKDNMHCIDBA')
# (1924, 'EOKCGPAADEMPCNHJNAIC')
# (1925, 'HEPNBJMJEMINBFLMMKPD')
# (1926, 'NOPACAKBJMOOOKDPPAGH')
# (1927, 'BPGCCAEJEONLNFHBJMGF')
# (1928, 'DBFACDMIIACAJFCFMFDL')
# (1929, 'ILDKNDHCMDGFECFEPBMH')
# (1930, 'FLCMFJCPEBMPEDJLOHMD')
# (1931, 'BKAAIADAENIMINJKDJIK')
# (1932, 'ILJODBABNFMIPBFFAKIF')
# (1933, 'NOCODPGALGDBNKKPDJKD')
# (1934, 'INLFGDNGNPLAMMJFEAOM')
# (1935, 'FGGIJIPKGFJDDKGMGFIA')
# (1936, 'GIJIMPJLKBKGFIHIONNC')
# (1937, 'KLBILEFPBLOCNCMKKJNP')
# (1938, 'FCBGPDIMLFKNOCFJHKBB')
# (1939, 'HEGNEPDGHHNFKHIDFEFJ')
# (1940, 'DGPCIIMEFNBBIMOCMGPN')
# (1941, 'IKLAMALHBMIOECIPOBLF')
# (1942, 'HCLHPPHIIDACBELEJLJD')
# (1943, 'GOJFHBKHHILFGEFADEHA')
# (1944, 'GHNHKCPFGEFGONCFBGFG')
# (1945, 'OADAKDLBNJCJOOBLFJPP')
# (1946, 'AILKEACBDIKCPOLJBJDL')
# (1947, 'FJLKOLOJGJHGBLLDNIGL')
# (1948, 'KMANGIOGBCAOOENGPGGL')
# (1949, 'KLJHAAKGHKOPHOOJJILN')
# (1950, 'AIPBJIBCBLFIJEAOGABD')
# (1951, 'OAGPLPCCGLLPLIEGKKLI')
# (1952, 'GADJNHLLJBDLJCCKOEHD')
# (1953, 'LACOOBNGEAEJDIIOAEGH')
# (1954, 'IEAOGDIBHAIHPLMLDOIH')
# (1955, 'CEMNBPEHHDHLJLDIGBCK')
# (1956, 'CBOPJCBJIHPGFHCKGHHK')
# (1957, 'AFEDPPHHKFFGGGGINGGH')
# (1958, 'CNKMKKHKNBAKCLGCEFDI')
# (1959, 'GIFLMFMEOOMEGLJCPMIO')
# (1960, 'BHEDKHNHAJEPHOCEDLJG')
# (1961, 'MGFHEOOAPNKDPAMJPDGP')
# (1962, 'LDHPMPMCHDOCJAOPHJAI')
# (1963, 'DCHAEJANBJEKGADAMFOD')
# (1964, 'DOPIOCLJNNIIAJANPECD')
# (1965, 'CGJHCPGECMMLIDFHJJCH')
# (1966, 'LPMJFODINNJCDCMDBJAO')
# (1967, 'IJBLCLMMHOOBLECPINHH')
# (1968, 'BLIHMGCEFKPAJAFPAGCC')
# (1969, 'OJPFGHPAAMIDFPINENIC')
# (1970, 'ACDPOINJENEDAPLPAPOO')
# (1971, 'BFIKMDPGLGDGIMEEGEHM')
# (1972, 'EPIOKMDKBGAJOLKBPKKD')
# (1973, 'BNEPBNKFPPPNJPEIOCOI')
# (1974, 'FHECBOJOLABNPDLKIPNI')
# (1975, 'HOPHAINANGKDBEKCBMHI')
# (1976, 'PJJFNFPKDECPABONJOGB')
# (1977, 'MLDPBMMGCIMAJNAOLKBG')
# (1978, 'IIHJGOPDJLFKHLDMFNFN')
# (1979, 'OLFGPBNPIJCJDJLGPDLB')
# (1980, 'JMFDFLHLEFGEKMFFNDHJ')
# (1981, 'DHHOFKCJNEKNBEEMDOIJ')
# (1982, 'GIADMLCMDJAFLFACFCGC')
# (1983, 'KBMNPEALHIGNBMAFGKOJ')
# (1984, 'CPIGJAFHDHNFOGLBFJEI')
# (1985, 'HBGJEEJAEKECHLIFMMFA')
# (1986, 'NCPDJPIOBLFMDFPNAOGO')
# (1987, 'LKKDOEKJLJBOOCGGFICO')
# (1988, 'KCEMEBIKAHKCDLPPKHMM')
# (1989, 'EPPIKFNFPJNIJNPOBAPJ')
# (1990, 'FODKKHGBGGNLFCEMKEIO')
# (1991, 'PCCKPAHBGPDOLFEMCCDG')
# (1992, 'JNEFKGKBMNDBLONEHBBA')
# (1993, 'DIOPOCJDLBMKAGCEHBIH')
# (1994, 'EKLMAEBOEKMBJLJICENL')
# (1995, 'NKEEGHNDAEKLCKMCAFLP')
# (1996, 'BMGGHJODNLHBNGAPKGJC')
# (1997, 'BEHHNEFBDAGKDHGONBNB')
# (1998, 'ILPKMHPCBNIBFCPGMJFM')
# (1999, 'KJJCLHCALEBFCHKCCOJD')
